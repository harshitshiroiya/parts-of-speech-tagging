# %%
###################################
# CS B551 Spring 2021, Assignment #3
#
# Your names and user ids:
#
# (Based on skeleton code by D. Crandall)
#


import random
import math
from collections import Counter


# We've set up a suggested code structure, but feel free to change it. Just
# make sure your code still works with the label.py and pos_scorer.py code
# that we've supplied.
#

# %%
class Solver:

    def __init__( self ) :
        # transition probability
        self.dict_tp = { }
        # emission probability
        self.dict_ep = { }
        # dictionary of word and pos
        self.dict_pos = { }
        # dictionary of word, pos and probability
        self.dict_bay_prob = { }
        # dictionary of word and pos , probability
        self.dict_rev_pos = { }
        # initiail probability
        self.init_prob = { }
        # pos count in training data
        self.pos_count = { }
        # word count in training data
        self.word_count = { }
    # Calculate the log of the posterior probability of a given sentence
    #  with a given part-of-speech labeling. Right now just returns -999 -- fix this!
    # def posterior(self, model, sentence, label):
    #     if model == "Simple":
    #         return -999
    #     elif model == "HMM":
    #         return -999
    #     elif model == "Complex":
    #         return -999
    #     else:
    #         print("Unknown algo!")


    def posterior(self, model, sentence, label):
        if model == "Simple":
            post_prob = 0.0
            for i in range( len( sentence ) ) :
                if ( sentence[ i ] , label[ i ] ) in self.dict_ep :
                    t = self.dict_ep[ ( sentence[ i ] , label[ i ] ) ]
                    post_prob += math.log( t )
                else :
                    post_prob += math.log( 1e-24 )
            return post_prob
        
        elif model == "Complex":
            post_prob = 0.0

            for i in range( len( sentence ) ) :
                if ( sentence[ i ] , label[ i ] ) in self.dict_ep :
                    t = self.pos_count[ label[ i ] ] * self.dict_ep[ ( sentence[ i ] , label[ i ] ) ]
                    post_prob += math.log( t )
                else :
                    post_prob += math.log( 1e-24 )
                    
            prev_pos = label[ 0 ]
            for i in range( 1 , len( label ) ) :
                t = self.dict_tp[ ( prev_pos , label[ i ] ) ]
                post_prob += math.log( t )
                prev_pos = label[ i ]        
            return post_prob
            
        elif model == "HMM":
            post_prob = 0.0
            for i in range( len( sentence ) ) :
                if ( sentence[ i ] , label[ i ] ) in self.dict_ep :
                    t = self.dict_ep[ ( sentence[ i ] , label[ i ] ) ]
                    post_prob += math.log( t )
                else :
                    post_prob += math.log( 1e-24 )
            
            prev_pos = label[ 0 ]
            for i in range( 1 , len( label ) ) :
                t = self.dict_tp[ ( prev_pos , label[ i ] ) ]
                post_prob += math.log( t )
                prev_pos = label[ i ]
            
            return post_prob
            
        else:
            print("Unknown algo!")

        

    def train(self, data):
        self.dict_pos = {'adj' : [], 
                'adv' : [], 
                'adp' : [], 
                'conj' : [], 
                'det' : [], 
                'noun' : [], 
                'num' : [], 
                'pron' : [], 
                'prt' : [], 
                'verb' : [], 
                'x' : [], 
                '.' : []}
        self.init_prob = {'adj' : 0, 
                'adv' : 0,
                'adp' : 0,
                'conj' : 0,
                'det' : 0,
                'noun' : 0,
                'num' : 0,
                'pron' : 0,
                'prt' : 0,
                'verb' : 0,
                'x' : 0,
                '.' : 0}
        self.dict_tp = { }

        self.pos_count = {'adj' : 0, 
                'adv' : 0,
                'adp' : 0,
                'conj' : 0,
                'det' : 0,
                'noun' : 0,
                'num' : 0,
                'pron' : 0,
                'prt' : 0,
                'verb' : 0,
                'x' : 0,
                '.' : 0}

        count = 0
        
        for elem in data :
            for pos in elem[ 1 ] :
                self.pos_count[ pos ] += 1
                count += 1
            for word in elem[ 0 ] :
                if word in self.word_count :
                    self.word_count[ word ] += 1
                else :
                    self.word_count[ word ] = 1
        
        for pos in self.pos_count :
            self.pos_count[ pos ] /= count
        
        for word in self.word_count :
            self.word_count[ word ] /= count
        
        for elem in data :
            if len( elem[ 1 ] ) > 1 :
                for i in range( len( elem[ 1 ] ) - 1 ) :
                    prev = elem[ 1 ][ i ]
                    nextt = elem[ 1 ][ i + 1 ]
                    self.init_prob[ prev ] += 1
                    if ( prev , nextt ) not in self.dict_tp:
                        self.dict_tp.update( { ( prev , nextt ) : 1 } )
                    else:
                        self.dict_tp[ ( prev , nextt ) ] += 1
                    self.dict_pos[ elem[ 1 ][ i ] ].append( elem[ 0 ][ i ] )
                self.dict_pos[ elem[ 1 ][ i + 1 ] ].append( elem[ 0 ][ i + 1 ] )
        
        normal = sum( self.init_prob.values( ) )
        
        for elem in self.init_prob.keys( ) :
            self.init_prob[ elem ] /= normal
        
        for elem in data :
            for i in range( len( elem[ 0 ] ) ) :
                if elem[ 0 ][ i ] not in self.dict_rev_pos :    
                    self.dict_rev_pos[ elem[ 0 ][ i ] ] = [ elem[ 1 ][ i ] ]
                else :
                    self.dict_rev_pos[ elem[ 0 ][ i ] ].append( elem[ 1 ][ i ] )
            
        summ = sum( self.dict_tp.values( ) )
        for i in self.dict_tp:
            self.dict_tp[ i ] = ( float( self.dict_tp[ i ] / summ ) )
        self.dict_ep = { }
        for pos, words in self.dict_pos.items():
            counts = Counter(words)
            counts = Counter (th for th in counts.elements())
        
        for pos, words in self.dict_pos.items():
            normal = 0
            counts= Counter(words)
            counts = Counter (th for th in counts.elements())
            for elem, co in counts.items( ) :
                normal += co
            for elem, co in counts.items( ) :
                self.dict_ep.update( { ( elem , pos ) :  co / normal } )
        
        self.dict_bay_prob = { }
        
        for word , pos in self.dict_rev_pos.items():
            normal = 0
            counts = Counter( pos )
            counts = Counter ( th for th in counts.elements( ) )
            for elem , co in counts.items( ) :
                normal += co
            for elem, co in counts.items( ) :
                if word not in self.dict_bay_prob :
                    self.dict_bay_prob.update( { word : [ [ co / normal , elem ] ] } )
                else :
                    self.dict_bay_prob[ word ].append( [ co / normal , elem ] )
        
        x=['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.' ]
        
        # replacing all the empty elements in the transition probability
        # by a downscaled value.
        temp=[]
        for i in x:
            for j in x:
                temp.append((i,j))
        
        l=list(self.dict_tp)
        
        diff=list(set(temp)-set(l))
        tp_min = min( self.dict_tp.values( ) )
        for i in diff :
            self.dict_tp[i] = tp_min / 20.0 #0.0
        pass



    def simplified(self, sentence):       
        ans = [ ]
        for word in list( sentence ) :
            if word in self.dict_rev_pos :
                temp = [ ]
                for elem in self.dict_bay_prob[ word ] :
                    temp.append( elem[ 0 ] )
                ans.append( self.dict_bay_prob[ word ][ temp.index( max( temp ) ) ][ 1 ] )
            else :
                ans.append( 'x' )
        return ans



    def hmm_viterbi(self, sentence):
        curr_dist ={'adj' : [], 
               'adv' : [], 
               'adp' : [], 
               'conj' : [], 
               'det' : [], 
               'noun' : [], 
               'num' : [], 
               'pron' : [], 
               'prt' : [], 
               'verb' : [], 
               'x' : [], 
               '.' : []}
        
        states = [ 'adj' ,
               'adv' ,
               'adp' ,
               'conj' ,
               'det' ,
               'noun' , 
               'num' , 
               'pron' ,
               'prt' ,
               'verb' ,
               'x',
               '.' ]
        
        ans = [ ]
        prev_pos = ''
        
        y = {'adj' : None , 
               'adv' : None ,
               'adp' : None ,
               'conj' : None , 
               'det' : None , 
               'noun' : None , 
               'num' : None , 
               'pron' : None , 
               'prt' : None , 
               'verb' : None , 
               'x' : None , 
               '.' : None }



        word = list( sentence )[ 0 ]
        p = 0.0
        for pos in states :
            if ( word , pos ) in self.dict_ep :
                p = self.dict_ep[ ( word , pos ) ] * self.init_prob[ pos ]
                curr_dist[ pos ].append( ( "noun" , p ) )
            else :
                curr_dist[ pos ].append( ( "noun" , 1e-8 ) )
        
        ans.append( prev_pos )
        for word in list( sentence )[ 1: ] :
            t = y
            for pos in states :
                max_p = 0.0
                for prev_pos , prev_prob in curr_dist.items( ) :
                    if ( word , pos ) in self.dict_ep :
                        temp = prev_prob[ -1 ][ 1 ] * self.dict_ep[ ( word , pos ) ] * self.dict_tp[ ( prev_pos , pos ) ]
                        if max_p < temp :
                            max_p = temp
                            new_pos = prev_pos
                if max_p == 0.0 :
                    for prev_pos , prev_prob in curr_dist.items( ) :
                        temp = prev_prob[ -1 ][ 1 ] * self.dict_tp[ ( prev_pos , pos ) ] * 5e-7
                        if max_p < temp :
                            max_p = temp
                            new_pos = prev_pos           
                t[ pos ] = ( new_pos , max_p )
            for i , j in t.items( ) :
                curr_dist[ i ].append( j )
        # Backtracking
        max_p = 0.0
        t_pos = ""
        temp = ""
        for pos , word in curr_dist.items( ) :
            if( max_p < word[ -1 ][ 1 ] ) :
                max_p = word[ -1 ][ 1 ]
                t_pos = word[ -1 ][ 0 ]
                temp = pos

        max_p = 0.0
        ans = [ ]
        if not temp :
            temp = 'noun'
        ans.append( temp )
        if not t_pos :
            max_p = 0.0
            for pos in states :
                if max_p < self.dict_tp[ ( ans[ -1 ] , pos ) ] :
                    max_p = self.dict_tp[ ( ans[ -1 ] , pos ) ]
                    t_pos = pos
        
        ans.append( t_pos )
        
        
        
        for i in range( len( sentence ) - 2 , 0 , -1 ) :
            if t_pos :
                t_pos = curr_dist[ t_pos ][ i ][ 0 ]
            else :
                max_p = 0.0
                for pos in states :
                    if max_p < self.dict_tp[ ans[ -1 ] ][ pos ] :
                        max_p = self.dict_tp[ ans[ -1 ] ][ pos ]
                        t_pos = pos

            ans.append( t_pos )
        ans.reverse( )
        return ans[ :len( sentence ) ]




    def complex_mcmc(self, sentence):

            ans = [ "noun" ] * len( sentence )
            states = [ 'adj' ,
                'adv' ,
                'adp' ,
                'conj' ,
                'det' ,
                'noun' , 
                'num' , 
                'pron' ,
                'prt' ,
                'verb' ,
                'x',
                '.' ]
            bias_prob = [ ]

            for word in list( sentence ) :
                temp = [ ]
                for pos in states :
                    if ( word , pos ) in self.dict_ep :           
                        temp.append( self.dict_ep[ ( word , pos ) ] )
                    else :
                        temp.append( 2.0 )

                min_temp = min( temp )
                
                for i in range( len( temp ) ) :
                    if temp[ i ] == 2.0 :
                        temp[ i ] = min_temp * 1e-12
                summ = sum( temp )
                
                for i in range( len( temp ) ) :
                    temp[ i ] /= summ
                x = 0.0
                for i in range( len( temp ) ) :
                    x += temp[ i ]
                    temp[ i ] = x
                bias_prob.append( temp )

            ans = [ ]
        
            l = 0
            for l in range(len( sentence )) :
                k = 1000
                ans.append( [ ] )
                while( k > 0 ) :
                    k -= 1
                    ran = random.random()
                    for i in range( 12 ) :
                        if( ran <= bias_prob[ l ][ i ] ) :
                            ans[ l ].append( states[ i ] )
                            break
            
            sol = [ ]
            for elem in ans :
                sol.append( elem[ -1 ] )
                #sol.append( max([(elem.count(chr),chr) for chr in set(elem)])[ 1 ] )
            return sol


    # def solve(self, model, sentence):
    #         if model == "Simple":
    #             return self.simplified(sentence)
    #         elif model == "HMM":
    #             return self.hmm_viterbi(sentence)
    #         elif model == "Complex":
    #             return self.complex_mcmc(sentence)
    #         else:
    #             print("Unknown algo!")

    def solve(self, model, sentence):
        if model == "Simple":
            return self.simplified(sentence)
        elif model == "Complex":
            return self.complex_mcmc(sentence)
        elif model == "HMM":
            return self.hmm_viterbi(sentence)
        else:
            print("Unknown algo!")

# %%
class Score:
    def __init__(self):
        self.word_scorecard = {}
        self.sentence_scorecard = {}
        self.word_count = 0
        self.sentence_count = 0


    def score(self, algo_outputs, gt):
        self.word_count += len(gt)
        self.sentence_count += 1

        for algo,labels in algo_outputs.items():
            correct = 0
            for j in range(0, len(gt)):
                correct += 1 if gt[j] == labels[j] else 0
        
            self.word_scorecard[algo] = self.word_scorecard.get(algo, 0) + correct
            self.sentence_scorecard[algo] = self.sentence_scorecard.get(algo, 0) + (correct == len(gt))


    def print_scores(self):
        print("\n==> So far scored %d sentences with %d words." % (self.sentence_count, self.word_count))
        print("                   Words correct:     Sentences correct: ")
        
        for i in sorted(self.word_scorecard):
            print("%18s:     %7.2f%%             %7.2f%%" % (i, self.word_scorecard[i]*100 / float(self.word_count), self.sentence_scorecard[i]*100 / float(self.sentence_count)))

    @staticmethod
    def print_helper(description, list, sentence):
        print (("%40s" % description) + " " + " ".join([(("%-" + str(max(4,len(sentence[i]))) + "s") % list[i]) for i in  range(0,len(list)) ] ) )

    @staticmethod
    def print_results(sentence, outputs, posteriors, models):
        Score.print_helper(" ".join([("%7s" % model) for model in models]), sentence, sentence)
        for algo in sorted(outputs.keys()):
            Score.print_helper(algo + "  "+" ".join(["%7.2f" % posteriors[algo][model] for model in models]), outputs[algo], sentence)

# %%
# Read in training or test data file
#
def read_data(fname):
    exemplars = []
    file = open(fname, 'r')
    for line in file:
        data = tuple([w.lower() for w in line.split()])
        exemplars += [ (data[0::2], data[1::2]), ]

    return exemplars


####################
# Main program
#

# a = "My name is Harshit and I am v"

if len(sys.argv) < 3:
    print("Usage: \n./label.py training_file test_file")
    sys.exit()

# (train_file, test_file) = sys.argv[1:3]

(train_file, test_file) = "/Users/harshitshiroiya/Desktop/abrajde-hshiroiy-rpp-a3-master/part1/bc.train","/Users/harshitshiroiya/Desktop/abrajde-hshiroiy-rpp-a3-master/part1/bc.test",


print("Learning model...")
solver = Solver()
train_data = read_data(train_file)
solver.train(train_data)

print("Loading test data...")
test_data = read_data(test_file)

print("Testing classifiers...")
scorer = Score()

Algorithms = ("Simple", "HMM", "Complex")
Algorithm_labels = [ str(i+1) + ". " + Algorithms[i] for i in range(0, len(Algorithms) ) ]
for (s, gt) in test_data:

    outputs = {"0. Ground truth" : gt}
        
    # run all algorithms on the sentence
    for (algo, label) in zip(Algorithms, Algorithm_labels):
        outputs[label] = solver.solve( algo, s) 

    # calculate posteriors for each output under each model
    posteriors = { o: { a: solver.posterior( a, s, outputs[o] ) for a in Algorithms } for o in outputs }
    Score.print_results(s, outputs, posteriors, Algorithms)
        
    scorer.score(outputs, gt)
    scorer.print_scores()
    
    print("----")
# Out:
# Learning model...
# Loading test data...
# Testing classifiers...
#                   Simple     HMM Complex at   the  same instant ,    nick hit  the  barrel and  threw himself upon the  smaller man  .
# 0. Ground truth   -82.27 -140.21 -176.15 adp  det  adj  noun    .    noun verb det  noun   conj verb  pron    adp  det  adj     noun .
#       1. Simple   -82.27 -140.21 -176.15 adp  det  adj  noun    .    noun verb det  noun   conj verb  pron    adp  det  adj     noun .
#          2. HMM   -82.27 -140.21 -176.15 adp  det  adj  noun    .    noun verb det  noun   conj verb  pron    adp  det  adj     noun .
#      3. Complex   -82.27 -140.21 -176.15 adp  det  adj  noun    .    noun verb det  noun   conj verb  pron    adp  det  adj     noun .
#
# ==> So far scored 1 sentences with 17 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:      100.00%              100.00%
#             2. HMM:      100.00%              100.00%
#         3. Complex:      100.00%              100.00%
# ----
#                   Simple     HMM Complex the  gun  fired next to   his  ear  with a    vicious whoosh like the  first stroke of   an   old  steam engine .
# 0. Ground truth  -159.67 -228.97 -268.51 det  noun verb  adp  adp  det  noun adp  det  adj     prt    adp  det  adj   noun   adp  det  adj  noun  noun   .
#       1. Simple  -154.71 -236.13 -277.91 det  noun verb  adj  prt  det  noun adp  det  adj     x      adp  det  adj   noun   adp  det  adj  noun  noun   .
#          2. HMM  -156.69 -219.04 -259.11 det  noun verb  adj  adp  det  noun adp  det  adj     noun   adp  det  adj   noun   adp  det  adj  noun  noun   .
#      3. Complex  -154.71 -226.01 -267.79 det  noun verb  adj  prt  det  noun adp  det  adj     .      adp  det  adj   noun   adp  det  adj  noun  noun   .
#
# ==> So far scored 2 sentences with 38 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.11%               50.00%
#             2. HMM:       94.74%               50.00%
#         3. Complex:       92.11%               50.00%
# ----
#                   Simple     HMM Complex at   the  same instant ,    elaine screamed wildly ,    the  sound ending abruptly as   nick went off  the  boat and  into the  water on   top  of   the  frantic ,    struggling poet .
# 0. Ground truth  -166.84 -277.13 -341.85 adp  det  adj  noun    .    noun   verb     adv    .    det  noun  verb   adv      adp  noun verb adp  det  noun conj adp  det  noun  adp  noun adp  det  adj     .    verb       noun .
#       1. Simple  -164.04 -278.83 -345.27 adp  det  adj  noun    .    noun   verb     adv    .    det  noun  verb   adv      adp  noun verb prt  det  noun conj adp  det  noun  adp  noun adp  det  adj     .    verb       noun .
#          2. HMM  -166.84 -277.13 -341.85 adp  det  adj  noun    .    noun   verb     adv    .    det  noun  verb   adv      adp  noun verb adp  det  noun conj adp  det  noun  adp  noun adp  det  adj     .    verb       noun .
#      3. Complex  -162.67 -285.07 -353.87 adp  det  adj  noun    .    noun   verb     adv    .    det  adj   verb   adv      adp  noun verb prt  det  noun conj adp  det  noun  adp  adj  adp  det  adj     .    verb       noun .
#
# ==> So far scored 3 sentences with 70 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       94.29%               33.33%
#             2. HMM:       97.14%               66.67%
#         3. Complex:       91.43%               33.33%
# ----
#                   Simple     HMM Complex the  moment the  sea  closed over nick ,    some atavistic sense warned him  that he   would survive in   this alien element only if   he   did  not  panic .
# 0. Ground truth  -234.63 -339.62 -395.60 det  noun   det  noun verb   adp  noun .    det  adj       noun  verb   pron adp  pron verb  verb    adp  det  adj   noun    adv  adp  pron verb adv  verb  .
#       1. Simple  -189.04 -306.07 -363.45 det  noun   det  noun verb   adp  noun .    det  x         noun  verb   pron adp  pron verb  verb    adp  det  adj   noun    adv  adp  pron verb adv  noun  .
#          2. HMM  -189.04 -293.55 -350.94 det  noun   det  noun verb   adp  noun .    det  noun      noun  verb   pron adp  pron verb  verb    adp  det  adj   noun    adv  adp  pron verb adv  noun  .
#      3. Complex  -188.20 -301.34 -360.44 det  noun   det  noun verb   prt  noun .    det  det       noun  verb   pron adp  pron verb  verb    adp  det  adj   noun    adv  adp  pron verb adv  noun  .
#
# ==> So far scored 4 sentences with 98 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.88%               25.00%
#             2. HMM:       95.92%               50.00%
#         3. Complex:       90.82%               25.00%
# ----
#                   Simple     HMM Complex but  the  murderer to   whom he   clung had  a    tremendous advantage .
# 0. Ground truth   -56.02  -99.23 -126.85 conj det  noun     adp  pron pron verb  verb det  adj        noun      .
#       1. Simple   -54.04 -104.00 -133.33 conj det  noun     prt  pron pron verb  verb det  adj        noun      .
#          2. HMM   -56.02  -99.23 -126.85 conj det  noun     adp  pron pron verb  verb det  adj        noun      .
#      3. Complex   -54.04 -104.00 -133.33 conj det  noun     prt  pron pron verb  verb det  adj        noun      .
#
# ==> So far scored 5 sentences with 110 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.64%               20.00%
#             2. HMM:       96.36%               60.00%
#         3. Complex:       90.91%               20.00%
# ----
#                   Simple     HMM Complex the  wide flippers on   poet's feet gave his  legs incredible power ,    driving the  two  of   them down into the  water as   they rolled over and  over .
# 0. Ground truth  -173.74 -292.52 -356.79 det  adj  noun     adp  noun   noun verb det  noun adj        noun  .    verb    det  num  adp  pron prt  adp  det  noun  adp  pron verb   prt  conj prt  .
#       1. Simple  -175.42 -306.03 -366.88 det  adj  x        adp  noun   noun verb det  noun adj        noun  .    verb    det  num  adp  pron prt  adp  det  noun  adp  pron verb   adp  conj adp  .
#          2. HMM  -175.42 -291.93 -352.78 det  adj  noun     adp  noun   noun verb det  noun adj        noun  .    verb    det  num  adp  pron prt  adp  det  noun  adp  pron verb   adp  conj adp  .
#      3. Complex  -175.39 -306.98 -373.99 det  adj  verb     prt  noun   noun verb det  noun adj        noun  .    verb    det  num  adp  pron prt  adp  det  noun  adv  pron verb   prt  conj prt  .
#
# ==> So far scored 6 sentences with 138 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.75%               16.67%
#             2. HMM:       95.65%               50.00%
#         3. Complex:       90.58%               16.67%
# ----
#                   Simple     HMM Complex poet was  the  captured ,    arms pinioned to   his  side ,    and  he   twisted convulsively trying to   escape .
# 0. Ground truth  -137.99 -209.64 -249.43 noun verb det  verb     .    noun verb     adp  det  noun .    conj pron verb    adv          verb   prt  verb   .
#       1. Simple  -136.01 -225.37 -266.87 noun verb det  verb     .    noun x        prt  det  noun .    conj pron verb    adv          verb   prt  verb   .
#          2. HMM  -141.43 -208.56 -246.16 noun verb det  verb     .    noun noun     adp  det  noun .    conj pron verb    adv          verb   adp  noun   .
#      3. Complex  -137.86 -226.47 -271.06 noun verb det  verb     .    noun adp      adp  det  noun .    conj pron verb    adv          x      prt  verb   .
#
# ==> So far scored 7 sentences with 157 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.36%               14.29%
#             2. HMM:       94.27%               42.86%
#         3. Complex:       90.45%               14.29%
# ----
#                   Simple     HMM Complex poet would escape ,    nick thought grimly ,    because he   wore the  apparatus which would keep him  alive under water .
# 0. Ground truth  -112.94 -197.75 -241.61 noun verb  verb   .    noun verb    adv    .    adp     pron verb det  noun      det   verb  verb pron adj   adp   noun  .
#       1. Simple  -112.94 -197.75 -241.61 noun verb  verb   .    noun verb    adv    .    adp     pron verb det  noun      det   verb  verb pron adj   adp   noun  .
#          2. HMM  -112.94 -197.75 -241.61 noun verb  verb   .    noun verb    adv    .    adp     pron verb det  noun      det   verb  verb pron adj   adp   noun  .
#      3. Complex  -114.59 -202.18 -246.57 noun verb  verb   .    noun noun    adv    .    adv     pron verb det  noun      det   verb  verb pron adj   adp   noun  .
#
# ==> So far scored 8 sentences with 178 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.26%               25.00%
#             2. HMM:       94.94%               50.00%
#         3. Complex:       90.45%               12.50%
# ----
#                   Simple     HMM Complex but  nick would not  let  go   .
# 0. Ground truth   -33.99  -58.33  -73.96 conj noun verb  adv  verb verb .
#       1. Simple   -33.99  -58.33  -73.96 conj noun verb  adv  verb verb .
#          2. HMM   -33.99  -58.33  -73.96 conj noun verb  adv  verb verb .
#      3. Complex   -33.99  -58.33  -73.96 conj noun verb  adv  verb verb .
#
# ==> So far scored 9 sentences with 185 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.51%               33.33%
#             2. HMM:       95.14%               55.56%
#         3. Complex:       90.81%               22.22%
# ----
#                   Simple     HMM Complex the  rubber and  glass face mask slipped from poet's forehead ,    bounced painlessly off  nick's chin ,    then disappeared .
# 0. Ground truth  -223.78 -294.47 -328.92 det  noun   conj noun  noun noun verb    adp  noun   noun     .    verb    adv        adp  noun   noun .    adv  verb        .
#       1. Simple  -220.98 -320.96 -357.13 det  noun   conj noun  noun noun verb    adp  noun   noun     .    verb    x          prt  x      noun .    adv  verb        .
#          2. HMM  -223.78 -291.08 -325.53 det  noun   conj noun  noun noun verb    adp  noun   noun     .    verb    noun       adp  det    noun .    adv  verb        .
#      3. Complex  -220.98 -296.35 -332.51 det  noun   conj noun  noun noun verb    adp  noun   noun     .    verb    .          prt  adp    noun .    adv  verb        .
#
# ==> So far scored 10 sentences with 205 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.68%               30.00%
#             2. HMM:       94.63%               50.00%
#         3. Complex:       90.24%               20.00%
# ----
#                   Simple     HMM Complex poet twisted again and  nick's knuckles scraped on   the  air  tank ,    ripping off  the  skin .
# 0. Ground truth  -149.80 -210.83 -244.20 noun verb    adv   conj noun   noun     verb    adp  det  noun noun .    verb    prt  det  noun .
#       1. Simple  -149.80 -223.56 -256.94 noun verb    adv   conj x      noun     verb    adp  det  noun noun .    verb    prt  det  noun .
#          2. HMM  -152.59 -209.02 -240.68 noun verb    adv   conj det    noun     verb    adp  det  noun noun .    verb    adp  det  noun .
#      3. Complex  -149.80 -217.01 -250.38 noun verb    adv   conj prt    noun     verb    adp  det  noun noun .    verb    prt  det  noun .
#
# ==> So far scored 11 sentences with 222 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.79%               27.27%
#             2. HMM:       94.14%               45.45%
#         3. Complex:       90.54%               18.18%
# ----
#                   Simple     HMM Complex for  a    split second ,    nick relaxed his  grip and  poet's slippery body spun completely around before nick could stop him  ,    holding him  now  from the  rear .
# 0. Ground truth  -173.08 -285.77 -347.52 adp  det  verb  noun   .    noun verb    det  noun conj noun   adj      noun verb adv        adv    adp    noun verb  verb pron .    verb    pron adv  adp  det  noun .
#       1. Simple  -167.03 -286.35 -349.44 adp  det  verb  adj    .    noun verb    det  noun conj noun   adj      noun verb adv        adp    adp    noun verb  verb pron .    verb    pron adv  adp  det  adj  .
#          2. HMM  -174.19 -283.74 -345.01 adp  det  noun  noun   .    noun verb    det  noun conj noun   adj      noun verb adv        adv    adp    noun verb  verb pron .    verb    pron adv  adp  det  noun .
#      3. Complex  -170.85 -296.39 -360.50 adp  det  noun  adj    .    noun verb    det  verb conj noun   adj      noun verb adv        adp    adv    noun verb  verb pron .    verb    pron adv  adp  det  adj  .
#
# ==> So far scored 12 sentences with 251 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.43%               25.00%
#             2. HMM:       94.42%               41.67%
#         3. Complex:       89.24%               16.67%
# ----
#                   Simple     HMM Complex something flailed at   the  side of   nick's head as   they rolled around and  around .
# 0. Ground truth  -163.56 -218.09 -247.40 noun      verb    adp  det  noun adp  noun   noun adp  pron verb   adv    conj adv    .
#       1. Simple  -164.53 -246.32 -273.59 noun      x       adp  det  noun adp  x      noun adp  pron verb   adp    conj adp    .
#          2. HMM  -163.56 -216.06 -245.38 noun      noun    adp  det  noun adp  det    noun adp  pron verb   adv    conj adv    .
#      3. Complex  -165.25 -237.15 -265.44 noun      prt     adp  det  noun adp  pron   noun adv  pron verb   adp    conj adp    .
#
# ==> So far scored 13 sentences with 266 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.35%               23.08%
#             2. HMM:       93.98%               38.46%
#         3. Complex:       87.97%               15.38%
# ----
#                   Simple     HMM Complex suddenly poet stopped struggling and  the  two  of   them hung suspended in   the  water ,    not  rising ,    not  sinking .
# 0. Ground truth   -92.21 -181.13 -230.08 adv      noun verb    verb       conj det  num  adp  pron verb verb      adp  det  noun  .    adv  verb   .    adv  verb    .
#       1. Simple   -92.21 -181.13 -230.08 adv      noun verb    verb       conj det  num  adp  pron verb verb      adp  det  noun  .    adv  verb   .    adv  verb    .
#          2. HMM   -92.21 -181.13 -230.08 adv      noun verb    verb       conj det  num  adp  pron verb verb      adp  det  noun  .    adv  verb   .    adv  verb    .
#      3. Complex   -92.21 -181.13 -230.08 adv      noun verb    verb       conj det  num  adp  pron verb verb      adp  det  noun  .    adv  verb   .    adv  verb    .
#
# ==> So far scored 14 sentences with 287 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.99%               28.57%
#             2. HMM:       94.43%               42.86%
#         3. Complex:       88.85%               21.43%
# ----
#                   Simple     HMM Complex a    sharp pain lanced across nick's chest and  a    bubble of   air  escaped from his  tortured lungs ,    joining dozens of   others that sailed lazily toward the  surface like helium balloons rising into the  sky  .
# 0. Ground truth  -360.80 -481.82 -545.04 det  adj   noun verb   adp    noun   noun  conj det  noun   adp  noun verb    adp  det  verb     noun  .    verb    noun   adp  noun   pron verb   adv    adp    det  noun    adp  noun   noun     verb   adp  det  noun .
#       1. Simple  -360.80 -516.49 -578.42 det  adj   noun x      adp    x      noun  conj det  noun   adp  noun verb    adp  det  verb     noun  .    verb    noun   adp  noun   adp  verb   x      adp    det  noun    adp  noun   noun     verb   adp  det  noun .
#          2. HMM  -360.80 -476.48 -538.40 det  adj   noun noun   adp    det    noun  conj det  noun   adp  noun verb    adp  det  verb     noun  .    verb    noun   adp  noun   adp  verb   noun   adp    det  noun    adp  noun   noun     verb   adp  det  noun .
#      3. Complex  -362.87 -494.41 -557.52 det  adj   noun verb   adp    prt    noun  conj det  noun   adp  noun verb    adp  det  verb     noun  .    verb    noun   adp  noun   adp  verb   prt    adp    det  adj     adp  noun   noun     verb   adp  det  noun .
#
# ==> So far scored 15 sentences with 323 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.64%               26.67%
#             2. HMM:       93.81%               40.00%
#         3. Complex:       88.85%               20.00%
# ----
#                   Simple     HMM Complex a    black ,    snake-like object swayed eerily in   front of   him  ,    spewing bubbles from its  flat cobra head .
# 0. Ground truth  -253.78 -325.98 -361.74 det  adj   .    adj        noun   verb   adv    adp  noun  adp  pron .    verb    noun    adp  det  adj  noun  noun .
#       1. Simple  -253.78 -359.20 -394.95 det  adj   .    x          noun   verb   adv    adp  noun  adp  pron .    x       noun    adp  det  adj  x     noun .
#          2. HMM  -256.21 -322.52 -357.09 det  noun  .    det        noun   verb   adv    adp  noun  adp  pron .    det     noun    adp  det  adj  noun  noun .
#      3. Complex  -258.84 -352.13 -392.52 det  adj   .    prt        noun   verb   adv    adp  noun  x    pron .    conj    noun    adp  det  adj  adp   noun .
#
# ==> So far scored 16 sentences with 343 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.25%               25.00%
#             2. HMM:       93.29%               37.50%
#         3. Complex:       88.34%               18.75%
# ----
#                   Simple     HMM Complex the  air  hose was  free !    !
# 0. Ground truth   -37.36  -60.34  -73.95 det  noun noun verb adj  .    .
#       1. Simple   -37.36  -60.34  -73.95 det  noun noun verb adj  .    .
#          2. HMM   -37.36  -60.34  -73.95 det  noun noun verb adj  .    .
#      3. Complex   -37.36  -60.34  -73.95 det  noun noun verb adj  .    .
#
# ==> So far scored 17 sentences with 350 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.43%               29.41%
#             2. HMM:       93.43%               41.18%
#         3. Complex:       88.57%               23.53%
# ----
#                   Simple     HMM Complex the  discovery struck nick like a    blow .
# 0. Ground truth   -46.98  -67.57  -82.04 det  noun      verb   noun adp  det  noun .
#       1. Simple   -46.98  -67.57  -82.04 det  noun      verb   noun adp  det  noun .
#          2. HMM   -46.98  -67.57  -82.04 det  noun      verb   noun adp  det  noun .
#      3. Complex   -46.98  -67.57  -82.04 det  noun      verb   noun adp  det  noun .
#
# ==> So far scored 18 sentences with 358 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.62%               33.33%
#             2. HMM:       93.58%               44.44%
#         3. Complex:       88.83%               27.78%
# ----
#                   Simple     HMM Complex desperately ,    nick flashed one  hand up   ,    catching poet's neck in   the  bend of   his  elbow .
# 0. Ground truth  -102.29 -169.21 -207.11 adv         .    noun verb    num  noun prt  .    verb     noun   noun adp  det  noun adp  det  noun  .
#       1. Simple  -101.40 -171.41 -209.79 adv         .    noun verb    num  noun prt  .    verb     noun   noun adp  det  verb adp  det  noun  .
#          2. HMM  -102.29 -169.21 -207.11 adv         .    noun verb    num  noun prt  .    verb     noun   noun adp  det  noun adp  det  noun  .
#      3. Complex  -103.65 -178.06 -220.54 x           .    noun verb    num  verb prt  .    verb     noun   noun adp  det  verb adp  det  noun  .
#
# ==> So far scored 19 sentences with 376 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               31.58%
#             2. HMM:       93.88%               47.37%
#         3. Complex:       88.56%               26.32%
# ----
#                   Simple     HMM Complex at   the  same instant ,    he   grabbed the  loose ,    writhing hose with his  other hand and  bit  down on   the  hard rubber mouthpiece .
# 0. Ground truth  -129.14 -217.67 -272.08 adp  det  adj  noun    .    pron verb    det  adj   .    verb     noun adp  det  adj   noun conj verb prt  adp  det  adj  noun   noun       .
#       1. Simple  -125.47 -214.41 -268.33 adp  det  adj  noun    .    pron verb    det  adj   .    verb     noun adp  det  adj   noun conj noun prt  adp  det  adj  noun   noun       .
#          2. HMM  -125.96 -213.84 -267.28 adp  det  adj  noun    .    pron verb    det  adj   .    noun     noun adp  det  adj   noun conj noun prt  adp  det  adj  noun   noun       .
#      3. Complex  -126.77 -223.03 -278.62 adp  det  adj  adj     .    pron verb    det  adv   .    verb     noun adp  det  adj   noun conj noun prt  adp  det  adj  noun   noun       .
#
# ==> So far scored 20 sentences with 401 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.02%               30.00%
#             2. HMM:       93.77%               45.00%
#         3. Complex:       88.53%               25.00%
# ----
#                   Simple     HMM Complex instinctively he   exhaled through his  nose then sucked in   the  air  from the  hose .
# 0. Ground truth  -126.44 -178.77 -210.63 adv           pron verb    adp     det  noun adv  verb   prt  det  noun adp  det  noun .
#       1. Simple  -124.03 -190.95 -221.10 adv           pron x       adp     det  noun adv  verb   adp  det  noun adp  det  noun .
#          2. HMM  -124.03 -171.86 -202.01 adv           pron verb    adp     det  noun adv  verb   adp  det  noun adp  det  noun .
#      3. Complex  -124.03 -190.95 -221.10 adv           pron x       adp     det  noun adv  verb   adp  det  noun adp  det  noun .
#
# ==> So far scored 21 sentences with 416 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.83%               28.57%
#             2. HMM:       93.75%               42.86%
#         3. Complex:       88.46%               23.81%
# ----
#                   Simple     HMM Complex at   once the  excruciating pain in   his  chest stopped and  he   was  seized with a    sudden ,    wild exultation .
# 0. Ground truth  -101.38 -173.13 -216.21 adp  adp  det  adj          noun adp  det  noun  verb    conj pron verb verb   adp  det  adj    .    adj  noun       .
#       1. Simple   -98.73 -173.50 -217.61 adp  adv  det  adj          noun adp  det  noun  verb    conj pron verb verb   adp  det  adj    .    adj  noun       .
#          2. HMM  -101.38 -173.13 -216.21 adp  adp  det  adj          noun adp  det  noun  verb    conj pron verb verb   adp  det  adj    .    adj  noun       .
#      3. Complex   -98.73 -173.50 -217.61 adp  adv  det  adj          noun adp  det  noun  verb    conj pron verb verb   adp  det  adj    .    adj  noun       .
#
# ==> So far scored 22 sentences with 436 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.97%               27.27%
#             2. HMM:       94.04%               45.45%
#         3. Complex:       88.76%               22.73%
# ----
#                   Simple     HMM Complex as   if   this was  a    signal ,    poet abruptly began to   thrash the  water and  the  quick movement slowly made them sink through the  water .
# 0. Ground truth  -165.95 -262.63 -317.31 adp  adp  det  verb det  noun   .    noun adv      verb  prt  verb   det  noun  conj det  adj   noun     adv    verb pron verb adp     det  noun  .
#       1. Simple  -165.96 -283.51 -337.72 adp  adp  det  verb det  noun   .    noun adv      verb  prt  x      det  noun  conj det  adj   noun     adv    verb pron noun adp     det  noun  .
#          2. HMM  -165.95 -262.63 -317.31 adp  adp  det  verb det  noun   .    noun adv      verb  prt  verb   det  noun  conj det  adj   noun     adv    verb pron verb adp     det  noun  .
#      3. Complex  -167.59 -282.72 -343.23 adv  adp  det  verb det  noun   .    noun adv      verb  prt  noun   det  noun  conj det  adj   noun     adv    x    pron verb adp     det  noun  .
#
# ==> So far scored 23 sentences with 462 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.99%               26.09%
#             2. HMM:       94.37%               47.83%
#         3. Complex:       88.74%               21.74%
# ----
#                   Simple     HMM Complex relentlessly ,    nick held on   ,    sucking on   the  hose ,    inhaling the  air  that belonged to   poet .
# 0. Ground truth  -147.61 -216.89 -255.08 adv          .    noun verb prt  .    verb    adp  det  noun .    verb     det  noun pron verb     adp  noun .
#       1. Simple  -144.71 -228.99 -265.88 adv          .    noun verb adp  .    verb    adp  det  noun .    x        det  noun adp  verb     prt  noun .
#          2. HMM  -146.69 -213.13 -248.31 adv          .    noun verb adp  .    verb    adp  det  noun .    adp      det  noun adp  verb     adp  noun .
#      3. Complex  -146.55 -227.48 -267.80 adv          .    noun verb prt  .    verb    prt  det  noun .    det      det  noun adp  verb     prt  noun .
#
# ==> So far scored 24 sentences with 481 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.48%               25.00%
#             2. HMM:       93.97%               45.83%
#         3. Complex:       88.36%               20.83%
# ----
#                   Simple     HMM Complex poet was  not  fighting nick now  .
# 0. Ground truth   -38.37  -64.16  -78.96 noun verb adv  verb     noun adv  .
#       1. Simple   -38.37  -64.16  -78.96 noun verb adv  verb     noun adv  .
#          2. HMM   -38.37  -64.16  -78.96 noun verb adv  verb     noun adv  .
#      3. Complex   -38.37  -64.16  -78.96 noun verb adv  verb     noun adv  .
#
# ==> So far scored 25 sentences with 488 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.60%               28.00%
#             2. HMM:       94.06%               48.00%
#         3. Complex:       88.52%               24.00%
# ----
#                   Simple     HMM Complex harbor point sticks out  into the  ocean like the  fat  neck of   a    steamer clam .
# 0. Ground truth  -138.37 -186.80 -216.61 noun   noun  verb   prt  adp  det  noun  adp  det  adj  noun adp  det  noun    noun .
#       1. Simple  -136.98 -198.69 -228.02 noun   noun  noun   prt  adp  det  noun  adp  det  adj  noun adp  det  x       noun .
#          2. HMM  -136.98 -186.18 -215.50 noun   noun  noun   prt  adp  det  noun  adp  det  adj  noun adp  det  noun    noun .
#      3. Complex  -141.07 -196.62 -225.24 verb   noun  noun   prt  adp  det  noun  adp  det  noun noun adp  det  num     noun .
#
# ==> So far scored 26 sentences with 504 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.47%               26.92%
#             2. HMM:       94.05%               46.15%
#         3. Complex:       88.10%               23.08%
# ----
#                   Simple     HMM Complex it's a    rich village but  not  much for  action --   too  many solid residents ,    not  enough tourists or   working stiffs .
# 0. Ground truth  -156.03 -244.70 -295.34 prt  det  adj  noun    conj adv  adj  adp  noun   .    adv  adj  adj   noun      .    adv  adj    noun     conj verb    noun   .
#       1. Simple  -155.33 -259.48 -310.61 prt  det  adj  noun    conj adv  adj  adp  noun   .    adv  adj  adj   noun      .    adv  adv    noun     conj verb    x      .
#          2. HMM  -156.03 -244.70 -295.34 prt  det  adj  noun    conj adv  adj  adp  noun   .    adv  adj  adj   noun      .    adv  adj    noun     conj verb    noun   .
#      3. Complex  -155.02 -250.00 -301.62 prt  det  adj  noun    conj adv  adv  adp  noun   .    adv  adj  adj   noun      .    adv  adv    noun     conj verb    .      .
#
# ==> So far scored 27 sentences with 526 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.44%               25.93%
#             2. HMM:       94.30%               48.15%
#         3. Complex:       88.02%               22.22%
# ----
#                   Simple     HMM Complex it's at   the  far  end  of   the  county and  the  last time i    came here was  for  a    hit  and  run  manslaughter --   about seven months ago  .
# 0. Ground truth  -122.19 -230.17 -295.08 prt  adp  det  adj  noun adp  det  noun   conj det  adj  noun pron verb adv  verb adp  det  noun conj noun noun         .    adv   num   noun   adv  .
#       1. Simple  -115.17 -232.30 -297.63 prt  adp  det  adv  noun adp  det  noun   conj det  adj  noun pron verb adv  verb adp  det  verb conj verb noun         .    adp   num   noun   adv  .
#          2. HMM  -121.15 -228.10 -292.47 prt  adp  det  adj  noun adp  det  noun   conj det  adj  noun pron verb adv  verb adp  det  noun conj verb noun         .    adp   num   noun   adv  .
#      3. Complex  -114.81 -234.23 -300.59 prt  adp  det  adv  noun adp  det  noun   conj det  adj  noun pron verb adv  verb adp  det  verb conj verb noun         .    adv   num   noun   adv  .
#
# ==> So far scored 28 sentences with 554 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.16%               25.00%
#             2. HMM:       94.22%               46.43%
#         3. Complex:       88.09%               21.43%
# ----
#                   Simple     HMM Complex chief bob  moore looked his  same hick-self ;    ;
# 0. Ground truth  -104.23 -131.00 -146.00 noun  noun noun  verb   det  adj  noun      .    .
#       1. Simple  -102.21 -141.31 -157.50 adj   noun noun  verb   det  adj  x         .    .
#          2. HMM  -102.21 -128.70 -144.89 adj   noun noun  verb   det  adj  noun      .    .
#      3. Complex  -102.21 -136.02 -152.21 adj   noun noun  verb   det  adj  num       .    .
#
# ==> So far scored 29 sentences with 563 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.94%               24.14%
#             2. HMM:       94.14%               44.83%
#         3. Complex:       87.92%               20.69%
# ----
#                   Simple     HMM Complex a    man  mountain running to   lard in   his  middle-age .
# 0. Ground truth   -56.69  -83.27 -101.19 det  noun noun     verb    adp  noun adp  det  noun       .
#       1. Simple   -54.71  -85.98 -105.60 det  noun noun     verb    prt  noun adp  det  noun       .
#          2. HMM   -56.69  -83.27 -101.19 det  noun noun     verb    adp  noun adp  det  noun       .
#      3. Complex   -54.71  -85.98 -105.60 det  noun noun     verb    prt  noun adp  det  noun       .
#
# ==> So far scored 30 sentences with 573 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.92%               23.33%
#             2. HMM:       94.24%               46.67%
#         3. Complex:       87.96%               20.00%
# ----
#                   Simple     HMM Complex seeing me   he   said with real surprise ,    ``   well ,    well ,    ain't we   honored !    !
# 0. Ground truth   -84.67 -167.04 -210.81 verb   pron pron verb adp  adj  noun     .    .    prt  .    prt  .    verb  pron verb    .    .
#       1. Simple   -81.23 -158.17 -200.56 verb   pron pron verb adp  adj  noun     .    .    adv  .    adv  .    verb  pron verb    .    .
#          2. HMM   -81.23 -158.17 -200.56 verb   pron pron verb adp  adj  noun     .    .    adv  .    adv  .    verb  pron verb    .    .
#      3. Complex   -84.59 -169.68 -213.24 verb   pron pron verb adp  adj  verb     .    .    prt  .    adv  .    verb  pron verb    .    .
#
# ==> So far scored 31 sentences with 591 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.86%               22.58%
#             2. HMM:       94.08%               45.16%
#         3. Complex:       87.99%               19.35%
# ----
#                   Simple     HMM Complex hardly expected the  head of   county homicide up   for  this murder .
# 0. Ground truth   -60.58 -100.00 -124.73 adv    verb     det  noun adp  noun   noun     prt  adp  det  noun   .
#       1. Simple   -60.58 -100.00 -124.73 adv    verb     det  noun adp  noun   noun     prt  adp  det  noun   .
#          2. HMM   -60.58 -100.00 -124.73 adv    verb     det  noun adp  noun   noun     prt  adp  det  noun   .
#      3. Complex   -60.58 -100.00 -124.73 adv    verb     det  noun adp  noun   noun     prt  adp  det  noun   .
#
# ==> So far scored 32 sentences with 603 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.04%               25.00%
#             2. HMM:       94.20%               46.88%
#         3. Complex:       88.23%               21.88%
# ----
#                   Simple     HMM Complex you  sure climbed fast ,    jed  .
# 0. Ground truth   -41.56  -68.30  -85.29 pron adv  verb    adv  .    noun .
#       1. Simple   -39.96  -70.54  -87.03 pron adj  verb    adv  .    noun .
#          2. HMM   -41.56  -68.30  -85.29 pron adv  verb    adv  .    noun .
#      3. Complex   -39.96  -70.54  -87.03 pron adj  verb    adv  .    noun .
#
# ==> So far scored 33 sentences with 610 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.98%               24.24%
#             2. HMM:       94.26%               48.48%
#         3. Complex:       88.20%               21.21%
# ----
#                   Simple     HMM Complex rookie investigator last summer and  now  it's inspector jed  .
# 0. Ground truth   -67.51 -108.68 -130.59 noun   noun         adj  noun   conj adv  prt  noun      noun .
#       1. Simple   -67.51 -108.68 -130.59 noun   noun         adj  noun   conj adv  prt  noun      noun .
#          2. HMM   -67.51 -108.68 -130.59 noun   noun         adj  noun   conj adv  prt  noun      noun .
#      3. Complex   -67.51 -108.68 -130.59 noun   noun         adj  noun   conj adv  prt  noun      noun .
#
# ==> So far scored 34 sentences with 620 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.13%               26.47%
#             2. HMM:       94.35%               50.00%
#         3. Complex:       88.39%               23.53%
# ----
#                   Simple     HMM Complex took me   19   years to   become chief of   our  three man  police force .
# 0. Ground truth   -68.42 -128.89 -161.51 verb pron num  noun  prt  verb   noun  adp  det  num   noun noun   noun  .
#       1. Simple   -66.40 -129.64 -163.44 verb pron num  noun  prt  verb   adj   adp  det  num   noun noun   noun  .
#          2. HMM   -68.42 -128.89 -161.51 verb pron num  noun  prt  verb   noun  adp  det  num   noun noun   noun  .
#      3. Complex   -66.40 -129.64 -163.44 verb pron num  noun  prt  verb   adj   adp  det  num   noun noun   noun  .
#
# ==> So far scored 35 sentences with 634 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.17%               25.71%
#             2. HMM:       94.48%               51.43%
#         3. Complex:       88.49%               22.86%
# ----
#                   Simple     HMM Complex proves a    college education pays off  ''   .
# 0. Ground truth   -42.52  -70.75  -87.41 verb   det  noun    noun      verb prt  .    .
#       1. Simple   -42.52  -70.75  -87.41 verb   det  noun    noun      verb prt  .    .
#          2. HMM   -42.52  -70.75  -87.41 verb   det  noun    noun      verb prt  .    .
#      3. Complex   -42.52  -70.75  -87.41 verb   det  noun    noun      verb prt  .    .
#
# ==> So far scored 36 sentences with 642 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.28%               27.78%
#             2. HMM:       94.55%               52.78%
#         3. Complex:       88.63%               25.00%
# ----
#                   Simple     HMM Complex his  sarcasm was  followed by   a    stupid grin of   his  thick mouth and  bad  teeth .
# 0. Ground truth  -129.38 -178.57 -210.23 det  noun    verb verb     adp  det  adj    noun adp  det  adj   noun  conj adj  noun  .
#       1. Simple  -129.38 -191.08 -222.74 det  x       verb verb     adp  det  adj    noun adp  det  adj   noun  conj adj  noun  .
#          2. HMM  -129.38 -178.57 -210.23 det  noun    verb verb     adp  det  adj    noun adp  det  adj   noun  conj adj  noun  .
#      3. Complex  -129.38 -186.77 -218.42 det  num     verb verb     adp  det  adj    noun adp  det  adj   noun  conj adj  noun  .
#
# ==> So far scored 37 sentences with 658 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.34%               27.03%
#             2. HMM:       94.68%               54.05%
#         3. Complex:       88.75%               24.32%
# ----
#                   Simple     HMM Complex ``   i    guess it   helps ''   ,    i    said ,    paying no   attention to   his  ribbing .
# 0. Ground truth  -119.19 -180.40 -216.21 .    pron verb  pron verb  .    .    pron verb .    verb   det  noun      adp  det  noun    .
#       1. Simple  -117.21 -195.97 -233.49 .    pron verb  pron verb  .    .    pron verb .    verb   det  noun      prt  det  x       .
#          2. HMM  -119.19 -180.40 -216.21 .    pron verb  pron verb  .    .    pron verb .    verb   det  noun      adp  det  noun    .
#      3. Complex  -117.21 -192.67 -230.19 .    pron verb  pron verb  .    .    pron verb .    verb   det  noun      prt  det  adp     .
#
# ==> So far scored 38 sentences with 675 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.26%               26.32%
#             2. HMM:       94.81%               55.26%
#         3. Complex:       88.74%               23.68%
# ----
#                   Simple     HMM Complex ``   never could figure out  why  you  ever wanted to   be   a    cop  ,    jed  .
# 0. Ground truth   -75.43 -142.03 -180.85 .    adv   verb  verb   prt  adv  pron adv  verb   prt  verb det  noun .    noun .
#       1. Simple   -73.44 -141.42 -179.76 .    adv   verb  noun   prt  adv  pron adv  verb   prt  verb det  noun .    noun .
#          2. HMM   -76.52 -140.66 -177.29 .    adv   verb  noun   adp  adv  pron adv  verb   prt  verb det  noun .    noun .
#      3. Complex   -75.43 -142.03 -180.85 .    adv   verb  verb   prt  adv  pron adv  verb   prt  verb det  noun .    noun .
#
# ==> So far scored 39 sentences with 691 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.32%               25.64%
#             2. HMM:       94.65%               53.85%
#         3. Complex:       89.00%               25.64%
# ----
#                   Simple     HMM Complex you're not  only young but  well ,    you  don't even look like a    police officer .
# 0. Ground truth   -70.15 -139.42 -180.40 prt    adv  adv  adj   conj prt  .    pron verb  adv  verb adp  det  noun   noun    .
#       1. Simple   -68.44 -134.72 -175.01 prt    adv  adv  adj   conj adv  .    pron verb  adv  verb adp  det  noun   noun    .
#          2. HMM   -68.44 -134.72 -175.01 prt    adv  adv  adj   conj adv  .    pron verb  adv  verb adp  det  noun   noun    .
#      3. Complex   -68.44 -134.72 -175.01 prt    adv  adv  adj   conj adv  .    pron verb  adv  verb adp  det  noun   noun    .
#
# ==> So far scored 40 sentences with 707 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.37%               25.00%
#             2. HMM:       94.63%               52.50%
#         3. Complex:       89.11%               25.00%
# ----
#                   Simple     HMM Complex a    runt with narrow shoulders and  that brush haircut hell ,    you'd pass for  a    juvenile delinquent of   the  hotrod set  .
# 0. Ground truth  -264.34 -340.56 -381.78 det  noun adp  adj    noun      conj det  noun  noun    prt  .    prt   verb adp  det  noun     noun       adp  det  noun   noun .
#       1. Simple  -257.16 -373.82 -415.44 det  x    adp  adj    noun      conj adp  noun  x       noun .    prt   verb adp  det  adj      adj        adp  det  x      verb .
#          2. HMM  -261.58 -331.99 -372.03 det  noun adp  adj    noun      conj det  noun  adp     noun .    prt   verb adp  det  adj      noun       adp  det  noun   noun .
#      3. Complex  -262.84 -370.33 -420.16 x    conj adp  adj    noun      conj pron verb  conj    prt  .    prt   noun adp  det  adj      adj        adp  det  adj    verb .
#
# ==> So far scored 41 sentences with 729 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.53%               24.39%
#             2. HMM:       94.38%               51.22%
#         3. Complex:       88.07%               24.39%
# ----
#                   Simple     HMM Complex in   my   day  the  first requirement for  a    cop  was  to   look like the  law  ,    big  and  tough .
# 0. Ground truth   -80.96 -151.58 -194.68 adp  det  noun det  adj   noun        adp  det  noun verb prt  verb adp  det  noun .    adj  conj adj   .
#       1. Simple   -80.96 -151.58 -194.68 adp  det  noun det  adj   noun        adp  det  noun verb prt  verb adp  det  noun .    adj  conj adj   .
#          2. HMM   -80.96 -151.58 -194.68 adp  det  noun det  adj   noun        adp  det  noun verb prt  verb adp  det  noun .    adj  conj adj   .
#      3. Complex   -80.96 -151.58 -194.68 adp  det  noun det  adj   noun        adp  det  noun verb prt  verb adp  det  noun .    adj  conj adj   .
#
# ==> So far scored 42 sentences with 749 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.79%               26.19%
#             2. HMM:       94.53%               52.38%
#         3. Complex:       88.38%               26.19%
# ----
#                   Simple     HMM Complex man  ,    when my   275  pounds and  six-four comes along ,    why  it's the  same as   another badge .
# 0. Ground truth  -139.01 -226.57 -270.60 noun .    adv  det  num  noun   conj num      verb  adv   .    adv  prt  det  adj  adp  det     noun  .
#       1. Simple  -139.64 -234.42 -277.43 noun .    adv  det  num  noun   conj x        verb  adp   .    adv  prt  det  adj  adp  det     noun  .
#          2. HMM  -184.76 -259.54 -299.32 noun .    adv  det  noun noun   conj noun     verb  adv   .    adv  prt  det  adj  adp  det     noun  .
#      3. Complex  -139.73 -228.86 -273.91 noun .    adv  det  num  noun   conj adp      verb  adv   .    adv  prt  det  adj  adv  det     noun  .
#
# ==> So far scored 43 sentences with 768 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.76%               25.58%
#             2. HMM:       94.40%               51.16%
#         3. Complex:       88.41%               25.58%
# ----
#                   Simple     HMM Complex when i    say  move ,    a    guy  moves ''   !    !
# 0. Ground truth   -52.54  -94.07 -118.11 adv  pron verb verb .    det  noun verb  .    .    .
#       1. Simple   -52.54  -94.07 -118.11 adv  pron verb verb .    det  noun verb  .    .    .
#          2. HMM   -54.08  -93.81 -117.37 adv  pron verb verb .    det  noun noun  .    .    .
#      3. Complex   -55.34  -99.10 -124.53 adv  pron prt  verb .    det  noun noun  .    .    .
#
# ==> So far scored 44 sentences with 779 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.89%               27.27%
#             2. HMM:       94.35%               50.00%
#         3. Complex:       88.32%               25.00%
# ----
#                   Simple     HMM Complex ``   don't worry about my   being tough ,    moore .
# 0. Ground truth   -53.43  -89.38 -109.52 .    verb  verb  adp   det  verb  adj   .    noun  .
#       1. Simple   -53.43  -89.38 -109.52 .    verb  verb  adp   det  verb  adj   .    noun  .
#          2. HMM   -53.43  -89.38 -109.52 .    verb  verb  adp   det  verb  adj   .    noun  .
#      3. Complex   -53.07  -92.34 -113.49 .    verb  verb  adv   det  verb  adj   .    noun  .
#
# ==> So far scored 45 sentences with 789 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.00%               28.89%
#             2. HMM:       94.42%               51.11%
#         3. Complex:       88.34%               24.44%
# ----
#                   Simple     HMM Complex also ,    it's far  too  early in   the  day  for  corny lines like the  bigger they come you've had  your gassy lecture ,    let's get  to   work .
# 0. Ground truth  -226.29 -339.56 -401.43 adv  .    prt  adv  adv  adv   adp  det  noun adp  adj   noun  adp  det  adj    pron verb prt    verb det  adj   noun    .    verb  verb prt  verb .
#       1. Simple  -224.89 -362.64 -423.54 adv  .    prt  adv  adv  adj   adp  det  noun adp  x     noun  adp  det  adj    pron verb prt    verb det  x     noun    .    verb  verb prt  noun .
#          2. HMM  -226.87 -333.48 -392.67 adv  .    prt  adv  adv  adj   adp  det  noun adp  det   noun  adp  det  adj    pron verb prt    verb det  noun  noun    .    verb  verb adp  noun .
# ...
#      3. Complex   -33.52  -57.59  -70.99 .    prt    det  verb  noun    .
#
# ==> So far scored 1982 sentences with 29231 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.69%
#             2. HMM:       94.52%               52.72%
#         3. Complex:       89.21%               29.82%
# ----
#                   Simple     HMM Complex the  bed  isn't made ,    but  you'll find plenty of   blankets there ''   .
# 0. Ground truth   -66.77 -121.01 -151.59 det  noun verb  verb .    conj prt    verb noun   adp  noun     adv   .    .
#       1. Simple   -64.44 -120.63 -151.90 det  noun verb  verb .    conj prt    verb noun   adp  noun     prt   .    .
#          2. HMM   -64.44 -120.63 -151.90 det  noun verb  verb .    conj prt    verb noun   adp  noun     prt   .    .
#      3. Complex   -64.44 -120.63 -151.90 det  noun verb  verb .    conj prt    verb noun   adp  noun     prt   .    .
#
# ==> So far scored 1983 sentences with 29245 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.67%
#             2. HMM:       94.52%               52.70%
#         3. Complex:       89.21%               29.80%
# ----
#                   Simple     HMM Complex ``   you're awfully kind ''   ,    the  girl said .
# 0. Ground truth   -45.89  -88.77 -112.04 .    prt    adv     adj  .    .    det  noun verb .
#       1. Simple   -43.96  -85.97 -108.07 .    prt    adv     noun .    .    det  noun verb .
#          2. HMM   -89.21 -125.72 -144.76 .    prt    verb    noun .    .    det  noun verb .
#      3. Complex   -43.96  -85.97 -108.07 .    prt    adv     noun .    .    det  noun verb .
#
# ==> So far scored 1984 sentences with 29255 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.65%
#             2. HMM:       94.52%               52.67%
#         3. Complex:       89.21%               29.79%
# ----
#                   Simple     HMM Complex ``   we'll pay  you  back if   you'll let  us   .
# 0. Ground truth   -46.42  -94.00 -121.29 .    prt   verb pron adv  adp  prt    verb pron .
#       1. Simple   -46.42  -94.00 -121.29 .    prt   verb pron adv  adp  prt    verb pron .
#          2. HMM   -46.42  -94.00 -121.29 .    prt   verb pron adv  adp  prt    verb pron .
#      3. Complex   -46.42  -94.00 -121.29 .    prt   verb pron adv  adp  prt    verb pron .
#
# ==> So far scored 1985 sentences with 29265 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.68%
#             2. HMM:       94.52%               52.70%
#         3. Complex:       89.21%               29.82%
# ----
#                   Simple     HMM Complex some way  ''   .
# 0. Ground truth   -14.36  -24.01  -31.77 det  noun .    .
#       1. Simple   -14.36  -24.01  -31.77 det  noun .    .
#          2. HMM   -14.36  -24.01  -31.77 det  noun .    .
#      3. Complex   -14.36  -24.01  -31.77 det  noun .    .
#
# ==> So far scored 1986 sentences with 29269 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.71%
#             2. HMM:       94.52%               52.72%
#         3. Complex:       89.21%               29.86%
# ----
#                   Simple     HMM Complex ``   it's all  right ''   ,    he   said .
# 0. Ground truth   -31.26  -72.56  -95.65 .    prt  adv  adj   .    .    pron verb .
#       1. Simple   -28.91  -71.02  -93.62 .    prt  prt  noun  .    .    pron verb .
#          2. HMM   -28.91  -71.02  -93.62 .    prt  prt  noun  .    .    pron verb .
#      3. Complex   -28.91  -71.02  -93.62 .    prt  prt  noun  .    .    pron verb .
#
# ==> So far scored 1987 sentences with 29278 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.70%
#             2. HMM:       94.51%               52.69%
#         3. Complex:       89.21%               29.84%
# ----
#                   Simple     HMM Complex ``   i    get  up   early .
# 0. Ground truth   -21.53  -47.30  -63.57 .    pron verb prt  adv   .
#       1. Simple   -20.99  -47.15  -62.94 .    pron verb prt  adj   .
#          2. HMM   -24.98  -46.78  -60.85 .    pron verb adp  adj   .
#      3. Complex   -20.99  -47.15  -62.94 .    pron verb prt  adj   .
#
# ==> So far scored 1988 sentences with 29284 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.68%
#             2. HMM:       94.51%               52.67%
#         3. Complex:       89.21%               29.83%
# ----
#                   Simple     HMM Complex you'd better sleep ''   .
# 0. Ground truth   -26.63  -47.26  -60.19 prt   adv    verb  .    .
#       1. Simple   -26.67  -44.40  -56.37 prt   adj    noun  .    .
#          2. HMM   -26.67  -44.40  -56.37 prt   adj    noun  .    .
#      3. Complex   -26.63  -47.26  -60.19 prt   adv    verb  .    .
#
# ==> So far scored 1989 sentences with 29289 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.75%               37.66%
#             2. HMM:       94.50%               52.64%
#         3. Complex:       89.21%               29.86%
# ----
#                   Simple     HMM Complex jones followed him  into the  front room ,    closing the  door behind him  .
# 0. Ground truth   -66.52 -116.80 -146.57 noun  verb     pron adp  det  adj   noun .    verb    det  noun adp    pron .
#       1. Simple   -66.96 -116.59 -145.18 noun  verb     pron adp  det  noun  noun .    verb    det  noun adp    pron .
#          2. HMM   -66.96 -116.59 -145.18 noun  verb     pron adp  det  noun  noun .    verb    det  noun adp    pron .
#      3. Complex   -67.95 -121.24 -150.85 noun  verb     pron adp  det  noun  noun .    verb    det  noun adv    pron .
#
# ==> So far scored 1990 sentences with 29303 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.75%               37.64%
#             2. HMM:       94.50%               52.61%
#         3. Complex:       89.21%               29.85%
# ----
#                   Simple     HMM Complex he   said :    ``   if   it's all  right with you  ,    mr.  morgan ,    i'll sleep out  here on   the  couch .
# 0. Ground truth   -94.91 -191.89 -245.33 pron verb .    .    adp  prt  adv  adj   adp  pron .    noun noun   .    prt  verb  prt  adv  adp  det  noun  .
#       1. Simple   -92.71 -194.13 -246.60 pron verb .    .    adp  prt  prt  noun  adp  pron .    noun noun   .    prt  noun  prt  adv  adp  det  noun  .
#          2. HMM   -92.57 -190.39 -243.34 pron verb .    .    adp  prt  prt  noun  adp  pron .    noun noun   .    prt  verb  prt  adv  adp  det  noun  .
#      3. Complex   -91.47 -192.31 -246.44 pron verb .    .    adp  prt  prt  adj   adp  pron .    noun noun   .    prt  verb  prt  adv  adp  det  noun  .
#
# ==> So far scored 1991 sentences with 29325 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.75%               37.62%
#             2. HMM:       94.50%               52.59%
#         3. Complex:       89.21%               29.83%
# ----
#                   Simple     HMM Complex we   haven't slept together since we   started .
# 0. Ground truth   -43.18  -72.26  -91.79 pron verb    verb  adv      adp   pron verb    .
#       1. Simple   -43.18  -72.26  -91.79 pron verb    verb  adv      adp   pron verb    .
#          2. HMM   -43.18  -72.26  -91.79 pron verb    verb  adv      adp   pron verb    .
#      3. Complex   -43.18  -72.26  -91.79 pron verb    verb  adv      adp   pron verb    .
#
# ==> So far scored 1992 sentences with 29333 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.75%               37.65%
#             2. HMM:       94.50%               52.61%
#         3. Complex:       89.22%               29.87%
# ----
#                   Simple     HMM Complex i    just can't take any  chances on   getting her  pregnant ,    and  if   we   were sleeping together ''
# 0. Ground truth   -87.69 -165.25 -208.61 pron adv  verb  verb det  noun    adp  verb    pron adj      .    conj adp  pron verb verb     adv      .
#       1. Simple   -88.13 -159.97 -202.12 pron adv  verb  verb det  noun    adp  verb    det  adj      .    conj adp  pron verb verb     adv      .
#          2. HMM   -88.13 -159.97 -202.12 pron adv  verb  verb det  noun    adp  verb    det  adj      .    conj adp  pron verb verb     adv      .
#      3. Complex   -87.69 -165.25 -208.61 pron adv  verb  verb det  noun    adp  verb    pron adj      .    conj adp  pron verb verb     adv      .
#
# ==> So far scored 1993 sentences with 29351 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.75%               37.63%
#             2. HMM:       94.50%               52.58%
#         3. Complex:       89.22%               29.90%
# ----
#                   Simple     HMM Complex he   stopped ,    embarrassed ,    and  morgan said ,    ``   i    understand that ,    but  i    don't savvy why  you'd go   off  and  leave your jobs in   the  first place ''   .
# 0. Ground truth  -181.26 -315.06 -389.05 pron verb    .    verb        .    conj noun   verb .    .    pron verb       det  .    conj pron verb  verb  adv  prt   verb prt  conj verb  det  noun adp  det  adj   noun  .    .
#       1. Simple  -180.11 -328.61 -402.52 pron verb    .    verb        .    conj noun   verb .    .    pron verb       adp  .    conj pron verb  x     adv  prt   verb prt  conj verb  det  noun adp  det  adj   noun  .    .
#          2. HMM  -180.11 -314.00 -387.90 pron verb    .    verb        .    conj noun   verb .    .    pron verb       adp  .    conj pron verb  verb  adv  prt   verb prt  conj verb  det  noun adp  det  adj   noun  .    .
#      3. Complex  -184.32 -335.26 -415.39 pron verb    .    verb        .    conj noun   verb .    .    pron verb       pron .    adv  pron verb  pron  adv  prt   verb prt  conj verb  det  noun adp  det  adj   x     .    .
#
# ==> So far scored 1994 sentences with 29383 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.75%               37.61%
#             2. HMM:       94.50%               52.56%
#         3. Complex:       89.22%               29.89%
# ----
#                   Simple     HMM Complex ``   we   got  fired ''   ,    jones said .
# 0. Ground truth   -38.60  -71.99  -90.84 .    pron verb verb  .    .    noun  verb .
#       1. Simple   -38.60  -71.99  -90.84 .    pron verb verb  .    .    noun  verb .
#          2. HMM   -38.60  -71.99  -90.84 .    pron verb verb  .    .    noun  verb .
#      3. Complex   -38.60  -71.99  -90.84 .    pron verb verb  .    .    noun  verb .
#
# ==> So far scored 1995 sentences with 29392 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.64%
#             2. HMM:       94.51%               52.58%
#         3. Complex:       89.22%               29.92%
# ----
#                   Simple     HMM Complex ``   we   had  to   do   something ''   .
# 0. Ground truth   -25.87  -54.69  -73.29 .    pron verb prt  verb noun      .    .
#       1. Simple   -25.87  -54.69  -73.29 .    pron verb prt  verb noun      .    .
#          2. HMM   -25.87  -54.69  -73.29 .    pron verb prt  verb noun      .    .
#      3. Complex   -25.87  -54.69  -73.29 .    pron verb prt  verb noun      .    .
#
# ==> So far scored 1996 sentences with 29400 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.68%
#             2. HMM:       94.51%               52.61%
#         3. Complex:       89.23%               29.96%
# ----
#                   Simple     HMM Complex they were a    pair of   lost ,    whipped kids ,    morgan thought as   he   went to   bed  .
# 0. Ground truth   -84.65 -147.42 -183.68 pron verb det  noun adp  verb .    verb    noun .    noun   verb    adp  pron verb adp  noun .
#       1. Simple   -82.67 -150.13 -188.10 pron verb det  noun adp  verb .    verb    noun .    noun   verb    adp  pron verb prt  noun .
#          2. HMM   -84.65 -147.42 -183.68 pron verb det  noun adp  verb .    verb    noun .    noun   verb    adp  pron verb adp  noun .
#      3. Complex   -84.15 -150.75 -188.24 pron verb det  noun adp  verb .    verb    noun .    noun   noun    adp  pron verb prt  noun .
#
# ==> So far scored 1997 sentences with 29418 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.66%
#             2. HMM:       94.51%               52.63%
#         3. Complex:       89.23%               29.94%
# ----
#                   Simple     HMM Complex gavin paused wearily .
# 0. Ground truth   -31.39  -43.61  -52.07 noun  verb   adv     .
#       1. Simple   -31.39  -43.61  -52.07 noun  verb   adv     .
#          2. HMM   -31.39  -43.61  -52.07 noun  verb   adv     .
#      3. Complex   -31.39  -43.61  -52.07 noun  verb   adv     .
#
# ==> So far scored 1998 sentences with 29422 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.69%
#             2. HMM:       94.51%               52.65%
#         3. Complex:       89.23%               29.98%
# ----
#                   Simple     HMM Complex ``   you  can't stay here with me   .
# 0. Ground truth   -33.72  -65.68  -85.46 .    pron verb  verb adv  adp  pron .
#       1. Simple   -33.72  -65.68  -85.46 .    pron verb  verb adv  adp  pron .
#          2. HMM   -33.72  -65.68  -85.46 .    pron verb  verb adv  adp  pron .
#      3. Complex   -33.72  -65.68  -85.46 .    pron verb  verb adv  adp  pron .
#
# ==> So far scored 1999 sentences with 29430 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.72%
#             2. HMM:       94.51%               52.68%
#         3. Complex:       89.23%               30.02%
# ----
#                   Simple     HMM Complex it's late and  you  said they'd be   here by   dawn ''   .
# 0. Ground truth   -52.18 -104.78 -136.60 prt  adv  conj pron verb prt    verb adv  adp  noun .    .
#       1. Simple   -51.53 -103.18 -134.51 prt  adj  conj pron verb prt    verb adv  adp  noun .    .
#          2. HMM   -51.53 -103.18 -134.51 prt  adj  conj pron verb prt    verb adv  adp  noun .    .
#      3. Complex   -51.53 -103.18 -134.51 prt  adj  conj pron verb prt    verb adv  adp  noun .    .
#
# ==> So far scored 2000 sentences with 29442 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.70%
#             2. HMM:       94.51%               52.65%
#         3. Complex:       89.23%               30.00%
# ----
