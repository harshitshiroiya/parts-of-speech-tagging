# %%
import random
import sys
import os
import math
from collections import Counter
from pos_scorer import Score

# We've set up a suggested code structure, but feel free to change it. Just
# make sure your code still works with the label.py and pos_scorer.py code
# that we've supplied.
# The code is referred from https://github.com/Jashjeet/F19-B551-Residential-Elements-of-AI/tree/master/jsmadan-a3-master/part1 and Class exercise code from prof. D. Crandall

# %%
class Solver:

    position_count = {}
    word_count = {}
    word_location = {}
    word_location_probablity = {}
    transition_probablity = {}
    emission_probablity = {}
    p_word_pos = {}
    temp_word = {}
    start_probablity = {}
    
   
    def posterior(self, model, sentence, label):
        if model == "Simple":
            return -999
        elif model == "HMM":
            return -999
        elif model == "Complex":
            return -999
        else:
            print("Unknown algo!")

        

    def train(self, data):
        
        # The dictionary modification is refered from https://stackoverflow.com/questions/2974022/is-it-possible-to-assign-the-same-value-to-multiple-keys-in-a-dict-object-at-onc
        self.word_location = {'adj' : [], 'adv' : [], 'adp' : [], 'conj' : [], 'det' : [], 'noun' : [], 'num' : [], 'pron' : [], 'prt' : [], 'verb' : [], 'x' : [], '.' : []}
        
        self.start_probablity = {}
        self.start_probablity.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], 0 ))

        self.transition_probablity = { }
        
        self.position_count = {}
        self.position_count.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], 0 ))
        c = 0
        for component in data :
            component_len = len(component[ 1 ])
            if component_len > 1 :
                for i in range( component_len - 1)   :
                    previous = component[ 1 ][ i ]
                    next_component = component[ 1 ][ i + 1 ]
                    self.start_probablity[ previous ] = self.start_probablity[ previous ] + 1
                    if ( previous , next_component ) not in self.transition_probablity:
                        self.transition_probablity.update( { ( previous , next_component ) : 1 } )
                    else:
                        self.transition_probablity[ ( previous , next_component ) ] = self.transition_probablity[ ( previous , next_component ) ] + 1
                    self.word_location[ component[ 1 ][ i ] ].append( component[ 0 ][ i ] )
                self.word_location[ component[ 1 ][ i + 1 ] ].append( component[ 0 ][ i + 1 ] )

        for pos in self.position_count :
             for word in self.word_count :
                self.position_count[ pos ] = self.position_count[ pos ] / c
                self.word_count[ word ] = self.word_count[ word ] / c
        

        
        for component in data:
            for pos in component[ 1 ]:
                for word in component[ 0 ] :

                    self.position_count[ pos ] = self.position_count[ pos ] + 1
                    c = c + 1
                
                    if word in self.word_count :
                        self.word_count[word] = self.word_count[word] + 1
                    else:
                        self.word_count[ word ] = 1
        
        
                
        
        value = 0
        for i in self.start_probablity:
            value = value + self.start_probablity[ i ] 


        for component in self.start_probablity.keys( ) :
            self.start_probablity[ component ] =  self.start_probablity[ component ] / value
        
        for component in data :
            component_len1 = len( component[ 0 ] )
            for i in range( component_len1 ) :
                if component[ 0 ][ i ] not in self.p_word_pos :    
                    self.p_word_pos[ component[ 0 ][ i ] ] = [ component[ 1 ][ i ] ]
                else :
                    self.p_word_pos[ component[ 0 ][ i ] ].append( component[ 1 ][ i ] )
        total_value = 0    
        for i in self.transition_probablity:
            total_value = total_value + self.transition_probablity[ i ] 
        
        for i in self.transition_probablity:
            self.transition_probablity[ i ] = self.transition_probablity[ i ] / total_value  
        self.emission_probablity = { }
        
        for pos, words in self.word_location.items():
            c1 = Counter(words)
            c1 = Counter (th for th in c1.elements())
        
        for pos, words in self.word_location.items():
            value = 0
            c1= Counter(words)
            c1 = Counter (th for th in c1.elements())
            for component, co in c1.items( ) :
                value = value + co
            for component, co in c1.items( ) :
                self.emission_probablity.update( { ( component , pos ) :  co / value } )
        
        self.word_location_probablity = { }
        
        for word , pos in self.p_word_pos.items():
            value = 0
            c1 = Counter( pos )
            c1 = Counter ( th for th in c1.elements( ) )
            for component , co in c1.items( ) :
                value = value + co
            for component, co in c1.items( ) :
                if word not in self.word_location_probablity :
                    self.word_location_probablity.update( { word : [ [ co / value , component ] ] } )
                else :
                    self.word_location_probablity[ word ].append( [ co / value , component ] )
        
        parts=['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.' ]
        
        
        temp=[]
        for i in parts:
            for j in parts:
                temp.append((i,j))
        
        l=list(self.transition_probablity)
        
        difference=list(set(temp)-set(l))
        transition_min = min( self.transition_probablity.values( ) )
        for i in difference :
            self.transition_probablity[i] = transition_min / 20
        pass



    def simplified(self, sentence):       
        answer_list = [ ]
        sentence_list = list(sentence)
        for word in sentence_list :
            if word in self.p_word_pos :
                temp = [ ]
                for component in self.word_location_probablity[ word ] :
                    temp.append( component[ 0 ] )
                answer_list.append( self.word_location_probablity[ word ][ temp.index( max( temp ) ) ][ 1 ] )
            else :
                answer_list.append( 'x' )
        return answer_list



    def hmm_viterbi(self, sentence):
        curr_dist ={'adj' : [], 'adv' : [], 'adp' : [], 'conj' : [], 'det' : [], 'noun' : [], 'num' : [], 'pron' : [], 'prt' : [], 'verb' : [], 'x' : [], '.' : []}
        
        states = [ 'adj' ,'adv' ,'adp' ,'conj' ,'det' ,'noun' , 'num' , 'pron' ,'prt' ,'verb' ,'x','.' ]
        
        answer_list = [ ]
        previous_pos = ''
        
        
        figures = {}
        figures.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], None ))
        sentence_list = list( sentence )
        word = sentence_list[0]
        p = 0
        for pos in states :
            if ( word , pos ) in self.emission_probablity :
                m = self.emission_probablity[ ( word , pos ) ]
                n = self.start_probablity[ pos ]
                p = m * n
                curr_dist[ pos ].append(("noun",p))
            else :
                curr_dist[ pos ].append( ("noun",1e-4))
        
        answer_list.append( previous_pos )
        
        for word in sentence_list[ 1: ] :
            t = figures
            for pos in states :
                maximum_probablity = 0
                for previous_pos , previous_prob in curr_dist.items( ) :
                    if ( word , pos ) in self.emission_probablity :
                        temp = previous_prob[ -1 ][ 1 ] * self.emission_probablity[ ( word , pos ) ] * self.transition_probablity[ ( previous_pos , pos ) ]
                        if maximum_probablity < temp :
                            maximum_probablity = temp
                            new_pos = previous_pos
                if maximum_probablity == 0 :
                    for previous_pos , previous_prob in curr_dist.items( ) :
                        temp = previous_prob[ -1 ][ 1 ] * self.transition_probablity[ ( previous_pos , pos ) ] * 5e-7
                        if maximum_probablity < temp :
                            maximum_probablity = temp
                            new_pos = previous_pos           
                t[ pos ] = ( new_pos , maximum_probablity )
            for i , j in t.items( ) :
                curr_dist[ i ].append( j )
      
        # The logic used here is based on the code of https://github.com/PulkitMathur/Elements-of-Artificial-Intelligence/tree/master/Natural%20Language%20Processing/part1
      
        maximum_probablity = 0
        t_pos = ""
        temp = ""
        for (pos , word) in curr_dist.items( ) :
            if(maximum_probablity < word[ -1 ][ 1 ]) :
                maximum_probablity = word[ -1 ][ 1 ]
                t_pos = word[ -1 ][ 0 ]
                temp = pos

        maximum_probablity = 0
        answer_list = [ ]
        if not temp :
            temp = 'noun'
        answer_list.append( temp )
        if not t_pos :
            maximum_probablity = 0
            for pos in states :
                if maximum_probablity < self.transition_probablity[ ( answer_list[ -1 ] , pos ) ] :
                    maximum_probablity = self.transition_probablity[ ( answer_list[ -1 ] , pos ) ]
                    t_pos = pos
        
        answer_list.append( t_pos )
        
        
        sentence_len = len(sentence)
        for i in range( sentence_len - 2 , 0 , -1 ) :
            if t_pos :
                t_pos = curr_dist[ t_pos ][ i ][ 0 ]
            else :
                maximum_probablity = 0.0
                for pos in states :
                    if maximum_probablity < self.transition_probablity[ answer_list[ -1 ] ][ pos ] :
                        maximum_probablity = self.transition_probablity[ answer_list[ -1 ] ][ pos ]
                        t_pos = pos

            answer_list.append( t_pos )
        answer_list.reverse( )
        return answer_list[ :sentence_len ]




    def complex_mcmc(self, sentence):

            answer_list = [ "noun" ] * len( sentence )
            states = [ 'adj' ,'adv' ,'adp' ,'conj' ,'det' ,'noun' , 'num' , 'pron' ,'prt' ,'verb' ,'x','.' ]
            bias_prob = [ ]
            sentence_list = list( sentence )
            for word in sentence_list:
                temp = [ ]
                for pos in states :
                    if ( word , pos ) in self.emission_probablity :           
                        temp.append( self.emission_probablity[ ( word , pos ) ] )
                    else :
                        temp.append( 2 )

                min_temp = min( temp )
                
                for i in range( len( temp ) ) :
                    if temp[ i ] == 2 :
                        temp[ i ] = min_temp * 1e-24
                total_value = sum( temp )
                
                for i in range( len( temp ) ) :
                    temp[ i ] /= total_value
                x1 = 0
                for i in range( len( temp ) ) :
                    x1 += temp[ i ]
                    temp[ i ] = x1
                bias_prob.append( temp )

            answer_list = [ ]
        
            l = 0
            for l in range(len( sentence )) :
                k = 1000
                answer_list.append( [ ] )
                while( k > 0 ) :
                    k -= 1
                    ran = random.random()
                    for i in range( 12 ) :
                        if( ran <= bias_prob[ l ][ i ] ) :
                            answer_list[ l ].append( states[ i ] )
                            break
            
            solution = [ ]
            for component in answer_list :
                solution.append( component[ -1 ] )
            return solution




    def solve(self, model, sentence):
        if model == "Simple":
            return self.simplified(sentence)
        elif model == "Complex":
            return self.complex_mcmc(sentence)
        elif model == "HMM":
            return self.hmm_viterbi(sentence)
        else:
            print("Unknown algo!")

# %%
class Score:
    def __init__(self):
        self.word_scorecard = {}
        self.sentence_scorecard = {}
        self.word_count = 0
        self.sentence_count = 0


    def score(self, algo_outputs, gt):
        self.word_count += len(gt)
        self.sentence_count += 1

        for algo,labels in algo_outputs.items():
            correct = 0
            for j in range(0, len(gt)):
                correct += 1 if gt[j] == labels[j] else 0
        
            self.word_scorecard[algo] = self.word_scorecard.get(algo, 0) + correct
            self.sentence_scorecard[algo] = self.sentence_scorecard.get(algo, 0) + (correct == len(gt))


    def print_scores(self):
        print("\n==> So far scored %d sentences with %d words." % (self.sentence_count, self.word_count))
        print("                   Words correct:     Sentences correct: ")
        
        for i in sorted(self.word_scorecard):
            print("%18s:     %7.2f%%             %7.2f%%" % (i, self.word_scorecard[i]*100 / float(self.word_count), self.sentence_scorecard[i]*100 / float(self.sentence_count)))

    @staticmethod
    def print_helper(description, list, sentence):
        print (("%40s" % description) + " " + " ".join([(("%-" + str(max(5,len(sentence[i]))) + "s") % list[i]) for i in  range(0,len(list)) ] ) )

    @staticmethod
    def print_results(sentence, outputs, posteriors, models):
        Score.print_helper(" ".join([("%7s" % model) for model in models]), sentence, sentence)
        for algo in sorted(outputs.keys()):
            Score.print_helper(algo + "  "+" ".join([("%7.2f" % posteriors[algo][model]) if  algo in posteriors else " "*7 for model in models]), outputs[algo], sentence)

# %%
from pos_scorer import Score
from pos_solver import *
import sys

# Read in training or test data file
#
def read_data(fname):
    exemplars = []
    file = open(fname, 'r');
    for line in file:
        data = tuple([w.lower() for w in line.split()])
        exemplars += [ (data[0::2], data[1::2]), ]

    return exemplars


####################
# Main program
#

# if len(sys.argv) < 3:
#     print("Usage: \npython3 ./label.py training_file test_file")
#     sys.exit()

# (train_file, test_file) = sys.argv[1:3]
train_file = 'bc.train'
test_file = 'bc.test'

print("Learning model...")
solver = Solver()
train_data = read_data(train_file)
solver.train(train_data)

print("Loading test data...")
test_data = read_data(test_file)

print("Testing classifiers...")
scorer = Score()

Algorithms = ("Simple", "HMM", "Complex")
Algorithm_labels = [ str(i+1) + ". " + Algorithms[i] for i in range(0, len(Algorithms) ) ]
for (s, gt) in test_data:

    outputs = {"0. Ground truth" : gt}
        
    # run all algorithms on the sentence
    for (algo, label) in zip(Algorithms, Algorithm_labels):
        outputs[label] = solver.solve( algo, s) 

    # calculate posteriors for each output under each model
    posteriors = { o: { a: solver.posterior( a, s, outputs[o] ) for a in Algorithms } for o in outputs }
    Score.print_results(s, outputs, posteriors, Algorithms)

    scorer.score(outputs, gt)
    scorer.print_scores()
    
    print("----")
# Out:
# Learning model...
# Loading test data...
# Testing classifiers...
#                   Simple     HMM Complex at    the   same  instant ,     nick  hit   the   barrel and   threw himself upon  the   smaller man   .
# 0. Ground truth  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun  verb  det   noun   conj  verb  pron    adp   det   adj     noun  .
#       1. Simple  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun  verb  det   noun   conj  verb  pron    adp   det   adj     noun  .
#          2. HMM  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun  verb  det   noun   conj  verb  pron    adp   det   adj     noun  .
#      3. Complex  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun  verb  det   noun   conj  verb  pron    adv   det   adj     noun  .
#
# ==> So far scored 1 sentences with 17 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:      100.00%              100.00%
#             2. HMM:      100.00%              100.00%
#         3. Complex:       94.12%                0.00%
# ----
#                   Simple     HMM Complex the   gun   fired next  to    his   ear   with  a     vicious whoosh like  the   first stroke of    an    old   steam engine .
# 0. Ground truth  -999.00 -999.00 -999.00 det   noun  verb  adp   adp   det   noun  adp   det   adj     prt    adp   det   adj   noun   adp   det   adj   noun  noun   .
#       1. Simple  -999.00 -999.00 -999.00 det   noun  verb  adj   prt   det   noun  adp   det   adj     x      adp   det   adj   noun   adp   det   adj   noun  noun   .
#          2. HMM  -999.00 -999.00 -999.00 det   noun  verb  adj   adp   det   noun  adp   det   adj     noun   adp   det   adj   noun   adp   det   adj   noun  noun   .
#      3. Complex  -999.00 -999.00 -999.00 det   noun  verb  adj   prt   det   noun  adp   det   adj     det    adp   det   adj   noun   adp   det   adj   noun  noun   .
#
# ==> So far scored 2 sentences with 38 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.11%               50.00%
#             2. HMM:       94.74%               50.00%
#         3. Complex:       89.47%                0.00%
# ----
#                   Simple     HMM Complex at    the   same  instant ,     elaine screamed wildly ,     the   sound ending abruptly as    nick  went  off   the   boat  and   into  the   water on    top   of    the   frantic ,     struggling poet  .
# 0. Ground truth  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun   verb     adv    .     det   noun  verb   adv      adp   noun  verb  adp   det   noun  conj  adp   det   noun  adp   noun  adp   det   adj     .     verb       noun  .
#       1. Simple  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun   verb     adv    .     det   noun  verb   adv      adp   noun  verb  prt   det   noun  conj  adp   det   noun  adp   noun  adp   det   adj     .     verb       noun  .
#          2. HMM  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun   verb     adv    .     det   noun  verb   adv      adp   noun  verb  adp   det   noun  conj  adp   det   noun  adp   noun  adp   det   adj     .     verb       noun  .
#      3. Complex  -999.00 -999.00 -999.00 adp   det   adj   noun    .     noun   verb     adv    .     det   adj   verb   adv      adv   noun  verb  prt   det   noun  conj  x     det   noun  adp   adj   adp   det   adj     .     verb       noun  .
#
# ==> So far scored 3 sentences with 70 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       94.29%               33.33%
#             2. HMM:       97.14%               66.67%
#         3. Complex:       87.14%                0.00%
# ----
#                   Simple     HMM Complex the   moment the   sea   closed over  nick  ,     some  atavistic sense warned him   that  he    would survive in    this  alien element only  if    he    did   not   panic .
# 0. Ground truth  -999.00 -999.00 -999.00 det   noun   det   noun  verb   adp   noun  .     det   adj       noun  verb   pron  adp   pron  verb  verb    adp   det   adj   noun    adv   adp   pron  verb  adv   verb  .
#       1. Simple  -999.00 -999.00 -999.00 det   noun   det   noun  verb   adp   noun  .     det   x         noun  verb   pron  adp   pron  verb  verb    adp   det   adj   noun    adv   adp   pron  verb  adv   noun  .
#          2. HMM  -999.00 -999.00 -999.00 det   noun   det   noun  verb   adp   noun  .     det   noun      noun  verb   pron  adp   pron  verb  verb    adp   det   adj   noun    adv   adp   pron  verb  adv   noun  .
#      3. Complex  -999.00 -999.00 -999.00 det   noun   det   noun  verb   prt   noun  .     det   det       noun  verb   pron  pron  pron  verb  verb    adp   det   adj   noun    adv   adp   pron  verb  adv   noun  .
#
# ==> So far scored 4 sentences with 98 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.88%               25.00%
#             2. HMM:       95.92%               50.00%
#         3. Complex:       86.73%                0.00%
# ----
#                   Simple     HMM Complex but   the   murderer to    whom  he    clung had   a     tremendous advantage .
# 0. Ground truth  -999.00 -999.00 -999.00 conj  det   noun     adp   pron  pron  verb  verb  det   adj        noun      .
#       1. Simple  -999.00 -999.00 -999.00 conj  det   noun     prt   pron  pron  verb  verb  det   adj        noun      .
#          2. HMM  -999.00 -999.00 -999.00 conj  det   noun     adp   pron  pron  verb  verb  det   adj        noun      .
#      3. Complex  -999.00 -999.00 -999.00 conj  det   noun     prt   pron  pron  verb  verb  det   adj        noun      .
#
# ==> So far scored 5 sentences with 110 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.64%               20.00%
#             2. HMM:       96.36%               60.00%
#         3. Complex:       87.27%                0.00%
# ----
#                   Simple     HMM Complex the   wide  flippers on    poet's feet  gave  his   legs  incredible power ,     driving the   two   of    them  down  into  the   water as    they  rolled over  and   over  .
# 0. Ground truth  -999.00 -999.00 -999.00 det   adj   noun     adp   noun   noun  verb  det   noun  adj        noun  .     verb    det   num   adp   pron  prt   adp   det   noun  adp   pron  verb   prt   conj  prt   .
#       1. Simple  -999.00 -999.00 -999.00 det   adj   x        adp   noun   noun  verb  det   noun  adj        noun  .     verb    det   num   adp   pron  prt   adp   det   noun  adp   pron  verb   adp   conj  adp   .
#          2. HMM  -999.00 -999.00 -999.00 det   adj   noun     adp   noun   noun  verb  det   noun  adj        noun  .     verb    det   num   adp   pron  prt   adp   det   noun  adp   pron  verb   adp   conj  adp   .
#      3. Complex  -999.00 -999.00 -999.00 det   adj   noun     adp   noun   noun  verb  det   noun  adj        noun  .     verb    det   num   adp   pron  prt   adp   det   noun  adp   pron  verb   prt   conj  prt   .
#
# ==> So far scored 6 sentences with 138 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.75%               16.67%
#             2. HMM:       95.65%               50.00%
#         3. Complex:       89.86%               16.67%
# ----
#                   Simple     HMM Complex poet  was   the   captured ,     arms  pinioned to    his   side  ,     and   he    twisted convulsively trying to    escape .
# 0. Ground truth  -999.00 -999.00 -999.00 noun  verb  det   verb     .     noun  verb     adp   det   noun  .     conj  pron  verb    adv          verb   prt   verb   .
#       1. Simple  -999.00 -999.00 -999.00 noun  verb  det   verb     .     noun  x        prt   det   noun  .     conj  pron  verb    adv          verb   prt   verb   .
#          2. HMM  -999.00 -999.00 -999.00 verb  verb  det   verb     .     noun  noun     adp   det   noun  .     conj  pron  verb    adv          verb   adp   noun   .
#      3. Complex  -999.00 -999.00 -999.00 noun  verb  det   verb     .     noun  det      prt   det   noun  .     conj  pron  verb    adv          x      prt   verb   .
#
# ==> So far scored 7 sentences with 157 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.36%               14.29%
#             2. HMM:       93.63%               42.86%
#         3. Complex:       89.17%               14.29%
# ----
#                   Simple     HMM Complex poet  would escape ,     nick  thought grimly ,     because he    wore  the   apparatus which would keep  him   alive under water .
# 0. Ground truth  -999.00 -999.00 -999.00 noun  verb  verb   .     noun  verb    adv    .     adp     pron  verb  det   noun      det   verb  verb  pron  adj   adp   noun  .
#       1. Simple  -999.00 -999.00 -999.00 noun  verb  verb   .     noun  verb    adv    .     adp     pron  verb  det   noun      det   verb  verb  pron  adj   adp   noun  .
#          2. HMM  -999.00 -999.00 -999.00 verb  verb  verb   .     noun  verb    adv    .     adp     pron  verb  det   noun      det   verb  verb  pron  adj   adp   noun  .
#      3. Complex  -999.00 -999.00 -999.00 noun  verb  noun   .     noun  verb    adv    .     adv     pron  verb  det   noun      det   verb  verb  pron  adj   adv   noun  .
#
# ==> So far scored 8 sentences with 178 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.26%               25.00%
#             2. HMM:       93.82%               37.50%
#         3. Complex:       88.76%               12.50%
# ----
#                   Simple     HMM Complex but   nick  would not   let   go    .
# 0. Ground truth  -999.00 -999.00 -999.00 conj  noun  verb  adv   verb  verb  .
#       1. Simple  -999.00 -999.00 -999.00 conj  noun  verb  adv   verb  verb  .
#          2. HMM  -999.00 -999.00 -999.00 conj  noun  verb  adv   verb  verb  .
#      3. Complex  -999.00 -999.00 -999.00 conj  noun  verb  adv   verb  verb  .
#
# ==> So far scored 9 sentences with 185 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       93.51%               33.33%
#             2. HMM:       94.05%               44.44%
#         3. Complex:       89.19%               22.22%
# ----
#                   Simple     HMM Complex the   rubber and   glass face  mask  slipped from  poet's forehead ,     bounced painlessly off   nick's chin  ,     then  disappeared .
# 0. Ground truth  -999.00 -999.00 -999.00 det   noun   conj  noun  noun  noun  verb    adp   noun   noun     .     verb    adv        adp   noun   noun  .     adv   verb        .
#       1. Simple  -999.00 -999.00 -999.00 det   noun   conj  noun  noun  noun  verb    adp   noun   noun     .     verb    x          prt   x      noun  .     adv   verb        .
#          2. HMM  -999.00 -999.00 -999.00 det   noun   conj  noun  noun  noun  verb    adp   noun   noun     .     verb    noun       adp   det    noun  .     adv   verb        .
#      3. Complex  -999.00 -999.00 -999.00 det   noun   conj  noun  noun  noun  verb    adp   noun   noun     .     verb    noun       prt   conj   noun  .     adv   verb        .
#
# ==> So far scored 10 sentences with 205 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.68%               30.00%
#             2. HMM:       93.66%               40.00%
#         3. Complex:       88.78%               20.00%
# ----
#                   Simple     HMM Complex poet  twisted again and   nick's knuckles scraped on    the   air   tank  ,     ripping off   the   skin  .
# 0. Ground truth  -999.00 -999.00 -999.00 noun  verb    adv   conj  noun   noun     verb    adp   det   noun  noun  .     verb    prt   det   noun  .
#       1. Simple  -999.00 -999.00 -999.00 noun  verb    adv   conj  x      noun     verb    adp   det   noun  noun  .     verb    prt   det   noun  .
#          2. HMM  -999.00 -999.00 -999.00 verb  verb    adv   conj  det    noun     verb    adp   det   noun  noun  .     verb    adp   det   noun  .
#      3. Complex  -999.00 -999.00 -999.00 noun  verb    adv   conj  prt    noun     verb    adp   det   noun  noun  .     verb    prt   det   noun  .
#
# ==> So far scored 11 sentences with 222 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.79%               27.27%
#             2. HMM:       92.79%               36.36%
#         3. Complex:       89.19%               18.18%
# ----
#                   Simple     HMM Complex for   a     split second ,     nick  relaxed his   grip  and   poet's slippery body  spun  completely around before nick  could stop  him   ,     holding him   now   from  the   rear  .
# 0. Ground truth  -999.00 -999.00 -999.00 adp   det   verb  noun   .     noun  verb    det   noun  conj  noun   adj      noun  verb  adv        adv    adp    noun  verb  verb  pron  .     verb    pron  adv   adp   det   noun  .
#       1. Simple  -999.00 -999.00 -999.00 adp   det   verb  adj    .     noun  verb    det   noun  conj  noun   adj      noun  verb  adv        adp    adp    noun  verb  verb  pron  .     verb    pron  adv   adp   det   adj   .
#          2. HMM  -999.00 -999.00 -999.00 adp   det   noun  noun   .     noun  verb    det   noun  conj  noun   adj      noun  verb  adv        adv    adp    noun  verb  verb  pron  .     verb    pron  adv   adp   det   noun  .
#      3. Complex  -999.00 -999.00 -999.00 adp   det   noun  adj    .     noun  verb    det   verb  conj  noun   adj      noun  verb  adv        adv    adp    noun  verb  noun  pron  .     verb    pron  adv   adp   det   adj   .
#
# ==> So far scored 12 sentences with 251 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       92.43%               25.00%
#             2. HMM:       93.23%               33.33%
#         3. Complex:       88.45%               16.67%
# ----
#                   Simple     HMM Complex something flailed at    the   side  of    nick's head  as    they  rolled around and   around .
# 0. Ground truth  -999.00 -999.00 -999.00 noun      verb    adp   det   noun  adp   noun   noun  adp   pron  verb   adv    conj  adv    .
#       1. Simple  -999.00 -999.00 -999.00 noun      x       adp   det   noun  adp   x      noun  adp   pron  verb   adp    conj  adp    .
#          2. HMM  -999.00 -999.00 -999.00 noun      noun    adp   det   noun  adp   det    noun  adp   pron  verb   adv    conj  adv    .
#      3. Complex  -999.00 -999.00 -999.00 noun      prt     adp   det   noun  x     verb   noun  adv   pron  verb   adv    conj  adp    .
#
# ==> So far scored 13 sentences with 266 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.35%               23.08%
#             2. HMM:       92.86%               30.77%
#         3. Complex:       87.22%               15.38%
# ----
#                   Simple     HMM Complex suddenly poet  stopped struggling and   the   two   of    them  hung  suspended in    the   water ,     not   rising ,     not   sinking .
# 0. Ground truth  -999.00 -999.00 -999.00 adv      noun  verb    verb       conj  det   num   adp   pron  verb  verb      adp   det   noun  .     adv   verb   .     adv   verb    .
#       1. Simple  -999.00 -999.00 -999.00 adv      noun  verb    verb       conj  det   num   adp   pron  verb  verb      adp   det   noun  .     adv   verb   .     adv   verb    .
#          2. HMM  -999.00 -999.00 -999.00 det      noun  verb    verb       conj  det   num   adp   pron  verb  verb      adp   det   noun  .     adv   verb   .     adv   verb    .
#      3. Complex  -999.00 -999.00 -999.00 adv      noun  verb    verb       conj  det   num   adp   pron  verb  verb      prt   det   noun  .     adv   verb   .     adv   verb    .
#
# ==> So far scored 14 sentences with 287 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.99%               28.57%
#             2. HMM:       93.03%               28.57%
#         3. Complex:       87.80%               14.29%
# ----
#                   Simple     HMM Complex a     sharp pain  lanced across nick's chest and   a     bubble of    air   escaped from  his   tortured lungs ,     joining dozens of    others that  sailed lazily toward the   surface like  helium balloons rising into  the   sky   .
# 0. Ground truth  -999.00 -999.00 -999.00 det   adj   noun  verb   adp    noun   noun  conj  det   noun   adp   noun  verb    adp   det   verb     noun  .     verb    noun   adp   noun   pron  verb   adv    adp    det   noun    adp   noun   noun     verb   adp   det   noun  .
#       1. Simple  -999.00 -999.00 -999.00 det   adj   noun  x      adp    x      noun  conj  det   noun   adp   noun  verb    adp   det   verb     noun  .     verb    noun   adp   noun   adp   verb   x      adp    det   noun    adp   noun   noun     verb   adp   det   noun  .
#          2. HMM  -999.00 -999.00 -999.00 det   adj   noun  noun   adp    det    noun  conj  det   noun   adp   noun  verb    adp   det   verb     noun  .     verb    noun   adp   noun   adp   verb   noun   adp    det   noun    adp   noun   noun     verb   adp   det   noun  .
#      3. Complex  -999.00 -999.00 -999.00 det   adj   noun  adj    adp    adp    noun  conj  det   noun   adp   noun  verb    adp   det   verb     noun  .     verb    noun   adp   noun   pron  verb   det    adp    det   noun    adp   noun   noun     verb   adp   det   noun  .
#
# ==> So far scored 15 sentences with 323 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.64%               26.67%
#             2. HMM:       92.57%               26.67%
#         3. Complex:       88.24%               13.33%
# ----
#                   Simple     HMM Complex a     black ,     snake-like object swayed eerily in    front of    him   ,     spewing bubbles from  its   flat  cobra head  .
# 0. Ground truth  -999.00 -999.00 -999.00 det   adj   .     adj        noun   verb   adv    adp   noun  adp   pron  .     verb    noun    adp   det   adj   noun  noun  .
#       1. Simple  -999.00 -999.00 -999.00 det   adj   .     x          noun   verb   adv    adp   noun  adp   pron  .     x       noun    adp   det   adj   x     noun  .
#          2. HMM  -999.00 -999.00 -999.00 det   noun  .     det        noun   verb   adv    adp   noun  adp   pron  .     det     noun    adp   det   adj   noun  noun  .
#      3. Complex  -999.00 -999.00 -999.00 det   adj   .     pron       noun   verb   adv    adp   adj   adp   pron  .     det     noun    adp   det   adj   verb  noun  .
#
# ==> So far scored 16 sentences with 343 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.25%               25.00%
#             2. HMM:       92.13%               25.00%
#         3. Complex:       87.76%               12.50%
# ----
#                   Simple     HMM Complex the   air   hose  was   free  !     !
# 0. Ground truth  -999.00 -999.00 -999.00 det   noun  noun  verb  adj   .     .
#       1. Simple  -999.00 -999.00 -999.00 det   noun  noun  verb  adj   .     .
#          2. HMM  -999.00 -999.00 -999.00 det   noun

# 0. Ground truth  -999.00 -999.00 -999.00 adp   adp   det   adj          noun  adp   det   noun  verb    conj  pron  verb  verb   adp   det   adj    .     adj   noun       .
#       1. Simple  -999.00 -999.00 -999.00 adp   adv   det   adj          noun  adp   det   noun  verb    conj  pron  verb  verb   adp   det   adj    .     adj   noun       .
#          2. HMM  -999.00 -999.00 -999.00 adp   adp   det   adj          noun  adp   det   noun  verb    conj  pron  verb  verb   adp   det   adj    .     adj   noun       .
#      3. Complex  -999.00 -999.00 -999.00 adp   adp   det   adj          noun  adp   x     noun  verb    conj  pron  verb  verb   adp   det   adj    .     adj   noun       .
#
# ==> So far scored 22 sentences with 436 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.97%               27.27%
#             2. HMM:       92.66%               31.82%
#         3. Complex:       88.76%               13.64%
# ----
#                   Simple     HMM Complex as    if    this  was   a     signal ,     poet  abruptly began to    thrash the   water and   the   quick movement slowly made  them  sink  through the   water .
# 0. Ground truth  -999.00 -999.00 -999.00 adp   adp   det   verb  det   noun   .     noun  adv      verb  prt   verb   det   noun  conj  det   adj   noun     adv    verb  pron  verb  adp     det   noun  .
#       1. Simple  -999.00 -999.00 -999.00 adp   adp   det   verb  det   noun   .     noun  adv      verb  prt   x      det   noun  conj  det   adj   noun     adv    verb  pron  noun  adp     det   noun  .
#          2. HMM  -999.00 -999.00 -999.00 adp   adp   det   verb  det   noun   .     noun  adv      verb  prt   verb   det   noun  conj  det   adj   noun     adv    verb  pron  verb  adp     det   noun  .
#      3. Complex  -999.00 -999.00 -999.00 adp   adp   det   verb  det   noun   .     noun  adv      verb  prt   det    det   noun  conj  det   adj   noun     adv    x     pron  noun  prt     det   noun  .
#
# ==> So far scored 23 sentences with 462 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.99%               26.09%
#             2. HMM:       93.07%               34.78%
#         3. Complex:       88.53%               13.04%
# ----
#                   Simple     HMM Complex relentlessly ,     nick  held  on    ,     sucking on    the   hose  ,     inhaling the   air   that  belonged to    poet  .
# 0. Ground truth  -999.00 -999.00 -999.00 adv          .     noun  verb  prt   .     verb    adp   det   noun  .     verb     det   noun  pron  verb     adp   noun  .
#       1. Simple  -999.00 -999.00 -999.00 adv          .     noun  verb  adp   .     verb    adp   det   noun  .     x        det   noun  adp   verb     prt   noun  .
#          2. HMM  -999.00 -999.00 -999.00 noun         .     noun  verb  adp   .     verb    adp   det   noun  .     adp      det   noun  adp   verb     adp   noun  .
#      3. Complex  -999.00 -999.00 -999.00 adv          .     noun  verb  adp   .     verb    adp   det   noun  .     noun     det   noun  adp   verb     prt   noun  .
#
# ==> So far scored 24 sentences with 481 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.48%               25.00%
#             2. HMM:       92.52%               33.33%
#         3. Complex:       88.15%               12.50%
# ----
#                   Simple     HMM Complex poet  was   not   fighting nick  now   .
# 0. Ground truth  -999.00 -999.00 -999.00 noun  verb  adv   verb     noun  adv   .
#       1. Simple  -999.00 -999.00 -999.00 noun  verb  adv   verb     noun  adv   .
#          2. HMM  -999.00 -999.00 -999.00 verb  verb  adv   verb     noun  adv   .
#      3. Complex  -999.00 -999.00 -999.00 noun  verb  adv   verb     noun  adv   .
#
# ==> So far scored 25 sentences with 488 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.60%               28.00%
#             2. HMM:       92.42%               32.00%
#         3. Complex:       88.32%               16.00%
# ----
#                   Simple     HMM Complex harbor point sticks out   into  the   ocean like  the   fat   neck  of    a     steamer clam  .
# 0. Ground truth  -999.00 -999.00 -999.00 noun   noun  verb   prt   adp   det   noun  adp   det   adj   noun  adp   det   noun    noun  .
#       1. Simple  -999.00 -999.00 -999.00 noun   noun  noun   prt   adp   det   noun  adp   det   adj   noun  adp   det   x       noun  .
#          2. HMM  -999.00 -999.00 -999.00 det    noun  noun   prt   adp   det   noun  adp   det   adj   noun  adp   det   noun    noun  .
#      3. Complex  -999.00 -999.00 -999.00 verb   verb  noun   prt   adp   det   noun  adp   det   adj   noun  adp   det   conj    noun  .
#
# ==> So far scored 26 sentences with 504 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91

# 0. Ground truth  -999.00 -999.00 -999.00 noun  .     adv   det   num   noun   conj  num      verb  adv   .     adv   prt   det   adj   adp   det     noun  .
#       1. Simple  -999.00 -999.00 -999.00 noun  .     adv   det   num   noun   conj  x        verb  adp   .     adv   prt   det   adj   adp   det     noun  .
#          2. HMM  -999.00 -999.00 -999.00 noun  .     adv   det   noun  noun   conj  noun     verb  adv   .     adv   prt   det   adj   adp   det     noun  .
#      3. Complex  -999.00 -999.00 -999.00 noun  .     adv   det   num   noun   conj  pron     verb  adp   .     prt   prt   det   adj   adv   det     noun  .
#
# ==> So far scored 43 sentences with 768 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       90.76%               25.58%
#             2. HMM:       92.32%               32.56%
# ...
#          2. HMM  -999.00 -999.00 -999.00 det   noun  verb  verb  .     conj  prt    verb  noun   adp   noun     prt   .     .
#      3. Complex  -999.00 -999.00 -999.00 det   noun  verb  verb  .     conj  prt    verb  noun   adp   noun     prt   .     .
#
# ==> So far scored 1983 sentences with 29245 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.67%
#             2. HMM:       93.24%               42.86%
#         3. Complex:       88.80%               28.85%
# ----
#                   Simple     HMM Complex ``    you're awfully kind  ''    ,     the   girl  said  .
# 0. Ground truth  -999.00 -999.00 -999.00 .     prt    adv     adj   .     .     det   noun  verb  .
#       1. Simple  -999.00 -999.00 -999.00 .     prt    adv     noun  .     .     det   noun  verb  .
#          2. HMM  -999.00 -999.00 -999.00 .     prt    verb    noun  .     .     det   noun  verb  .
#      3. Complex  -999.00 -999.00 -999.00 .     prt    adv     noun  .     .     det   noun  verb  .
#
# ==> So far scored 1984 sentences with 29255 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.65%
#             2. HMM:       93.23%               42.84%
#         3. Complex:       88.80%               28.83%
# ----
#                   Simple     HMM Complex ``    we'll pay   you   back  if    you'll let   us    .
# 0. Ground truth  -999.00 -999.00 -999.00 .     prt   verb  pron  adv   adp   prt    verb  pron  .
#       1. Simple  -999.00 -999.00 -999.00 .     prt   verb  pron  adv   adp   prt    verb  pron  .
#          2. HMM  -999.00 -999.00 -999.00 .     prt   verb  pron  adv   adp   prt    verb  pron  .
#      3. Complex  -999.00 -999.00 -999.00 .     prt   verb  pron  adv   adp   prt    verb  pron  .
#
# ==> So far scored 1985 sentences with 29265 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.68%
#             2. HMM:       93.23%               42.87%
#         3. Complex:       88.80%               28.87%
# ----
#                   Simple     HMM Complex some  way   ''    .
# 0. Ground truth  -999.00 -999.00 -999.00 det   noun  .     .
#       1. Simple  -999.00 -999.00 -999.00 det   noun  .     .
#          2. HMM  -999.00 -999.00 -999.00 det   noun  .     .
#      3. Complex  -999.00 -999.00 -999.00 det   noun  .     .
#
# ==> So far scored 1986 sentences with 29269 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.71%
#             2. HMM:       93.24%               42.90%
#         3. Complex:       88.80%               28.90%
# ----
#                   Simple     HMM Complex ``    it's  all   right ''    ,     he    said  .
# 0. Ground truth  -999.00 -999.00 -999.00 .     prt   adv   adj   .     .     pron  verb  .
#       1. Simple  -999.00 -999.00 -999.00 .     prt   prt   noun  .     .     pron  verb  .
#          2. HMM  -999.00 -999.00 -999.00 .     prt   prt   noun  .     .     pron  verb  .
#      3. Complex  -999.00 -999.00 -999.00 .     prt   prt   adv   .     .     pron  verb  .
#
# ==> So far scored 1987 sentences with 29278 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37
words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.68%
#             2. HMM:       93.22%               42.84%
#         3. Complex:       88.82%               28.91%
# ----
#                   Simple     HMM Complex they  were  a     pair  of    lost  ,     whipped kids  ,     morgan thought as    he    went  to    bed   .
# 0. Ground truth  -999.00 -999.00 -999.00 pron  verb  det   noun  adp   verb  .     verb    noun  .     noun   verb    adp   pron  verb  adp   noun  .
#       1. Simple  -999.00 -999.00 -999.00 pron  verb  det   noun  adp   verb  .     verb    noun  .     noun   verb    adp   pron  verb  prt   noun  .
#          2. HMM  -999.00 -999.00 -999.00 pron  verb  det   noun  adp   verb  .     verb    noun  .     noun   verb    adp   pron  verb  adp   noun  .
#      3. Complex  -999.00 -999.00 -999.00 pron  verb  det   noun  adp   verb  .     verb    verb  .     noun   verb    adp   pron  verb  adp   noun  .
#
# ==> So far scored 1997 sentences with 29418 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.66%
#             2. HMM:       93.23%               42.86%
#         3. Complex:       88.82%               28.89%
# ----
#                   Simple     HMM Complex gavin paused wearily .
# 0. Ground truth  -999.00 -999.00 -999.00 noun  verb   adv     .
#       1. Simple  -999.00 -999.00 -999.00 noun  verb   adv     .
#          2. HMM  -999.00 -999.00 -999.00 verb  verb   adv     .
#      3. Complex  -999.00 -999.00 -999.00 noun  verb   adv     .
#
# ==> So far scored 1998 sentences with 29422 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.69%
#             2. HMM:       93.22%               42.84%
#         3. Complex:       88.82%               28.93%
# ----
#                   Simple     HMM Complex ``    you   can't stay  here  with  me    .
# 0. Ground truth  -999.00 -999.00 -999.00 .     pron  verb  verb  adv   adp   pron  .
#       1. Simple  -999.00 -999.00 -999.00 .     pron  verb  verb  adv   adp   pron  .
#          2. HMM  -999.00 -999.00 -999.00 .     pron  verb  verb  adv   adp   pron  .
#      3. Complex  -999.00 -999.00 -999.00 .     pron  verb  verb  adv   adp   pron  .
#
# ==> So far scored 1999 sentences with 29430 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.72%
#             2. HMM:       93.22%               42.87%
#         3. Complex:       88.83%               28.96%
# ----
#                   Simple     HMM Complex it's  late  and   you   said  they'd be    here  by    dawn  ''    .
# 0. Ground truth  -999.00 -999.00 -999.00 prt   adv   conj  pron  verb  prt    verb  adv   adp   noun  .     .
#       1. Simple  -999.00 -999.00 -999.00 prt   adj   conj  pron  verb  prt    verb  adv   adp   noun  .     .
#          2. HMM  -999.00 -999.00 -999.00 det   adj   conj  pron  verb  prt    verb  adv   adp   noun  .     .
#      3. Complex  -999.00 -999.00 -999.00 prt   adj   conj  pron  verb  prt    verb  adv   adp   noun  .     .
#
# ==> So far scored 2000 sentences with 29442 words.
#                    Words correct:     Sentences correct:
#    0. Ground truth:      100.00%              100.00%
#          1. Simple:       91.76%               37.70%
#             2. HMM:       93.22%               42.85%
#         3. Complex:       88.83%               28.95%
# ----

# %%
# def train(self, data):
word_count = {}
train_file = 'bc.train'
test_file = 'bc.test'

# print("Learning model...")
solver = Solver()
train_data = read_data(train_file)

data = train_data
# The dictionary modification is refered from https://stackoverflow.com/questions/2974022/is-it-possible-to-assign-the-same-value-to-multiple-keys-in-a-dict-object-at-onc
word_location = {'adj' : [], 'adv' : [], 'adp' : [], 'conj' : [], 'det' : [], 'noun' : [], 'num' : [], 'pron' : [], 'prt' : [], 'verb' : [], 'x' : [], '.' : []}

start_probablity = {}
start_probablity.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], 0 ))

transition_probablity = { }

position_count = {}
position_count.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], 0 ))
c = 0



for component in data :
    component_len = len(component[ 1 ])
    if component_len > 1 :
        for i in range( component_len - 1)   :
            previous = component[ 1 ][ i ]
            next_component = component[ 1 ][ i + 1 ]
            start_probablity[ previous ] = start_probablity[ previous ] + 1
            if ( previous , next_component ) not in transition_probablity:
                transition_probablity.update( { ( previous , next_component ) : 1 } )
            else:
                transition_probablity[ ( previous , next_component ) ] = transition_probablity[ ( previous , next_component ) ] + 1
            word_location[ component[ 1 ][ i ] ].append( component[ 0 ][ i ] )
        word_location[ component[ 1 ][ i + 1 ] ].append( component[ 0 ][ i + 1 ] )

for pos in position_count :
     for word in word_count :
        position_count[ pos ] = position_count[ pos ] / c
        word_count[ word ] = word_count[ word ] / c



# for component in data:
#     for pos in component[ 1 ]:
#         for word in component[ 0 ] :

#             self.position_count[ pos ] = self.position_count[ pos ] + 1
#             c = c + 1

#             if word in self.word_count :
#                 self.word_count[word] = self.word_count[word] + 1
#             else:
#                 self.word_count[ word ] = 1




# value = 0
# for i in self.start_probablity:
#     value = value + self.start_probablity[ i ] 


# for component in self.start_probablity.keys( ) :
#     self.start_probablity[ component ] =  self.start_probablity[ component ] / value

# for component in data :
#     component_len1 = len( component[ 0 ] )
#     for i in range( component_len1 ) :
#         if component[ 0 ][ i ] not in self.p_word_pos :    
#             self.p_word_pos[ component[ 0 ][ i ] ] = [ component[ 1 ][ i ] ]
#         else :
#             self.p_word_pos[ component[ 0 ][ i ] ].append( component[ 1 ][ i ] )
# total_value = 0    
# for i in self.transition_probablity:
#     total_value = total_value + self.transition_probablity[ i ] 

# for i in self.transition_probablity:
#     self.transition_probablity[ i ] = self.transition_probablity[ i ] / total_value  
# self.emission_probablity = { }

# for pos, words in self.word_location.items():
#     c1 = Counter(words)
#     c1 = Counter (th for th in c1.elements())

# for pos, words in self.word_location.items():
#     value = 0
#     c1= Counter(words)
#     c1 = Counter (th for th in c1.elements())
#     for component, co in c1.items( ) :
#         value = value + co
#     for component, co in c1.items( ) :
#         self.emission_probablity.update( { ( component , pos ) :  co / value } )

# self.word_location_probablity = { }

# for word , pos in self.p_word_pos.items():
#     value = 0
#     c1 = Counter( pos )
#     c1 = Counter ( th for th in c1.elements( ) )
#     for component , co in c1.items( ) :
#         value = value + co
#     for component, co in c1.items( ) :
#         if word not in self.word_location_probablity :
#             self.word_location_probablity.update( { word : [ [ co / value , component ] ] } )
#         else :
#             self.word_location_probablity[ word ].append( [ co / value , component ] )

# parts=['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.' ]


# temp=[]
# for i in parts:
#     for j in parts:
#         temp.append((i,j))

# l=list(self.transition_probablity)

# difference=list(set(temp)-set(l))
# transition_min = min( self.transition_probablity.values( ) )
# for i in difference :
#     self.transition_probablity[i] = transition_min / 20
# pass

# %%
# def train(self, data):
word_count = {}
train_file = 'bc.train'
test_file = 'bc.test'

# print("Learning model...")
solver = Solver()
train_data = read_data(train_file)

data = train_data
# The dictionary modification is refered from https://stackoverflow.com/questions/2974022/is-it-possible-to-assign-the-same-value-to-multiple-keys-in-a-dict-object-at-onc
word_location = {'adj' : [], 'adv' : [], 'adp' : [], 'conj' : [], 'det' : [], 'noun' : [], 'num' : [], 'pron' : [], 'prt' : [], 'verb' : [], 'x' : [], '.' : []}

start_probablity = {}
start_probablity.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], 0 ))

transition_probablity = { }

position_count = {}
position_count.update(dict.fromkeys(['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.'], 0 ))
c = 0

word_location_probablity = {}
emission_probablity = {}
p_word_pos = {}
temp_word = {}



for component in data :
    component_len = len(component[ 1 ])
    if component_len > 1 :
        for i in range( component_len - 1)   :
            previous = component[ 1 ][ i ]
            next_component = component[ 1 ][ i + 1 ]
            start_probablity[ previous ] = start_probablity[ previous ] + 1
            if ( previous , next_component ) not in transition_probablity:
                transition_probablity.update( { ( previous , next_component ) : 1 } )
            else:
                transition_probablity[ ( previous , next_component ) ] = transition_probablity[ ( previous , next_component ) ] + 1
            word_location[ component[ 1 ][ i ] ].append( component[ 0 ][ i ] )
        word_location[ component[ 1 ][ i + 1 ] ].append( component[ 0 ][ i + 1 ] )


        
# for pos in position_count :
#      for word in word_count :
#         position_count[ pos ] = position_count[ pos ] / c
#         word_count[ word ] = word_count[ word ] / c
        
        
for component in data:
    for pos in component[ 1 ]:
        for word in component[ 0 ] :

            position_count[ pos ] = position_count[ pos ] + 1
            c = c + 1

            if word in word_count :
                word_count[word] = word_count[word] + 1
            else:
                word_count[ word ] = 1
        
value = 0
for i in start_probablity:
    value = value + start_probablity[i] 
    
for component in start_probablity.keys( ) :
    start_probablity[ component ] =  start_probablity[ component ] / value

for component in data :
    component_len1 = len( component[ 0 ] )
    for i in range( component_len1 ) :
        if component[ 0 ][ i ] not in p_word_pos :    
            p_word_pos[ component[ 0 ][ i ] ] = [ component[ 1 ][ i ] ]
        else :
            p_word_pos[ component[ 0 ][ i ] ].append( component[ 1 ][ i ] )
total_value = 0    
for i in transition_probablity:
    total_value = total_value + transition_probablity[ i ] 
    
for i in transition_probablity:
    transition_probablity[ i ] = transition_probablity[ i ] / total_value  
emission_probablity = { }

for pos, words in word_location.items():
    c1 = Counter(words)
    c1 = Counter (th for th in c1.elements())
    
# print(c1)

for pos, words in word_location.items():
    value = 0
    c1= Counter(words)
    c1 = Counter (th for th in c1.elements())
    for component, co in c1.items( ) :
        value = value + co
    for component, co in c1.items( ) :
        emission_probablity.update( { ( component , pos ) :  co / value } )

        
word_location_probablity = { }

for word , pos in p_word_pos.items():
    value = 0
    c1 = Counter( pos )
    c1 = Counter ( th for th in c1.elements( ) )
    for component , co in c1.items( ) :
        value = value + co
    for component, co in c1.items( ) :
        if word not in word_location_probablity :
            word_location_probablity.update( { word : [ [ co / value , component ] ] } )
        else :
            word_location_probablity[ word ].append( [ co / value , component ] )

parts=['adj' ,'adv' ,'adp' ,'conj','det' ,'noun','num' ,'pron','prt' ,'verb','x'  ,'.' ]


temp=[]
for i in parts:
    for j in parts:
        temp.append((i,j))

l=list(transition_probablity)

difference=list(set(temp)-set(l))
transition_min = min(transition_probablity.values( ) )
for i in difference :
    transition_probablity[i] = transition_min / 20
pass


# print(p_word_pos.keys())
# print(word_count)
# print(position_count)
# print(c)
# print(value)
# print(data[0])

# %%
# print(word_location_probablity)

# %%
# print(emission_probablity)

# %%
# print(transition_probablity)

# %%
# print(p_word_pos['run'])
